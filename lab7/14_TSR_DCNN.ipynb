# %% [markdown]
# # Klasyfikacja znaków drogowych z wykorzystaniem DCNN
#
# Uwaga: ćwiczenie powstało w oparciu o następujący [tutorial](https://www.pyimagesearch.com/2019/11/04/traffic-sign-classification-with-keras-and-deep-learning/).
# Osoby zainteresowane tematem - moim zdaniem (Tomasz Kryjak) powinien to być każdy z Państwa - zachęcam do prześledzenia tego dokumentu bardziej szczegółowo.
#
# Inne podobne tutoriale:
# - https://chsasank.github.io/keras-tutorial.html
# - https://towardsdatascience.com/building-a-road-sign-classifier-in-keras-764df99fdd6a
#
#
# To krótkie ćwiczenie nie zastąpi pełnego kursu z AI, ale powinno pozwolić poznać podstawowe etapy związane z inżynierskim wykorzystaniem głębokich konwolucyjnych sieci neuronowych (**DCNN** - Deep Convolutional Neural Network).
#
# ## Założenia
#
# Poniższy notebook jest kompletny i gotowy do uruchomienia.
# Jedyne wyzwania (niekoniecznie trywialne) to sprawy techniczne.
# W przyszłości będzie to ulegało zmianom.
#
# Uwaga - czas obliczeń może być znaczny, ale można go wykorzystać np. na czytanie wskazanego tutoriala, tudzież analizę kodu.
#
# ## Instalacja i sprawy techniczne
#
# Notebook do działania potrzebuje pakietów:
# - OpenCV,
# - NumPy,
# - scikit-learn,
# - scikit-image,
# - imutils,
# - matplotlib,
# - TensorFlow 2.0 (CPU lub GPU).
#
# Opcje uruchomienia są dwie:
# - _Google Colaboratory_ - tam wszystko jest zainstalowane + mamy zasoby obliczeniowe, ale trzeba nieco pokombinować z dostarczeniem danych. Opis tej metody jest przedstawiony poniżej. Jest to opcja rekomendowana.
# - lokalnie (instalacja pakietów via *pip* lub poprzez PyCharm).
#
# Dodatkowo należy pobrać bazę danych [GTSRB](https://drive.google.com/file/d/1EQ-tyVHIdVaa4_1bob1zv8zgaVmvyyqV/view?usp=sharing) (German Traffic Sign Recognition Benchmark) - waży ona 300 MB.
# Baza zawiera ponad 50000 obrazków dla 43 klas znaków.
# Ma też niestety dwie istotne wady:
# - różna liczba przykładów z poszczególnych klas (od 180 do ponad 2000),
# - część znaków stanowi duże wyzwanie (słaba jakość, kontrast) - uczciwie mówiąc, niektóre trudno rozpoznać.
#
# Nie wchodząc zbytnio w szczegóły: sieć DCNN "uczy się" (jest uczona) na podstawie przykładów, podobnie jak uczymy się i my.
# I teraz np. jeśli rozwiążemy 10 zadań dotyczących całek i 100 zadań na temat pochodnych, to co na egzaminie nam wyjdzie lepiej?
#
# Stąd tego typu dysproporcja stanowi problem.
# Słaba jakość zdjęć też utrudnia uczenie.
#
# **W przypadku przetwarzania lokalnego bazę należy rozpakować.**
#
#
# ## Informacje wstępne o DCNN
#
# Co to jest sieć DCNN (Deep Convolutional Neural Network)?
#
# Jest to model naśladujący działanie ludzkiego mózgu (tu konkretnie: sposobu przetwarzania informacji wizyjnej).
# Przedstawienie całej teorii w notatniku nie jest specjalnie wygodne - zainteresowane osoby odsyłam do obszernej literatury.
# Bez wchodzenia w szczegóły, sieć można traktować jako czarną skrzynkę, która na wejściu dostaje obraz, a na wyjściu wyniki (klasy obiektów).
#
# Należy pamiętać, że sieć trzeba _nauczyć_.
# W uproszczeniu proces uczenia polega na tym, że prezentujemy sieci obraz, otrzymujemy jakiś wynik, porównujemy go z pożądanym i według specjalnego algorytmu modyfikujemy parametry sieci (tzw. _wsteczna propagacja błędu_).
# Uwaga: opisano tzw. uczenie nadzorowane (z "nauczycielem").
# Istnieje też uczenie bez nauczyciela (sieci samouczące) oraz ze wspomaganiem (reinforcement learning).
# Szczególnie to drugie jest bardzo ciekawe - warto sobie o tym poczytać.
# To właśnie ta metodologia stoi za sukcesami **AlphaGo** (w grze Go) czy też **AlphaStar** (w grze Starcraft).
#
# Mając nauczoną sieć, można przeprowadzić tzw. wnioskowanie (ang. *inference*).
#
# Warto też wiedzieć, że sieci konwolucyjne to jest jedna z możliwości, dedykowana dla obrazów.
# Dla innych zagadnień stosowane są inne modele.
# Ponadto w ramach samych DCNN występuje wiele różnych rozwiązań, choć są one zbudowane z mniej więcej podobnych "klocków".
#
# Źródła dodatkowych informacji:
# - https://en.wikipedia.org/wiki/Convolutional_neural_network,
# - https://d2l.ai/,
# - kursy na _Coursera_,
# - oraz naprawdę bardzo dużo innych źródeł.
#
#
# ## Co dzisiaj zrobimy?
#
# Przejdziemy przez następujące kroki:
# - utworzenie modelu (definicja architektury sieci),
# - implementacja funkcji do przygotowania zbioru uczącego,
# - przygotowanie danych,
# - uczenie,
# - analiza wyników uczenia,
# - testy - wnioskowanie.
#
# Bardziej szczegółowe komentarze są umieszczone w tekście.

# %%
# potrzebne biblioteki
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

from sklearn.metrics import classification_report
from skimage import transform
from skimage import exposure
from skimage import io

from imutils import paths

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import argparse
import random
import os
import pickle
import requests
import imutils
import cv2

matplotlib.use("Agg")

# Definicja architektury sieci do klasyfikacji
# Sieć składa się z:
# 5 warstw konwolucyjnych - Conv2D, po nich funkcja aktywacji (relu), normalizacja oraz podpróbkowanie (zmiana rozdzielczości)
# 2 warstw tzw. w pełni połączonych

# Uwaga: sieć ta jest zbliżona do rozwiązania AlexNet (https://en.wikipedia.org/wiki/AlexNet).
# Sam AlexNet natomiast to jedna z pierwszych (i na pewno najbardziej znanych) sieci konwolucyjnych.
# Jest tak m.in. przez sukces tego rozwiązania w konkursie ImageNet Large Scale Visual Recognition Challenge (ISLVRC).
# Artykuł opisujący tę sieć ma ponad 70000 cytowań.

class TrafficSignNet:
		@staticmethod
		def build(width, height, depth, classes):
				model = Sequential()
				inputShape = (height, width, depth)
				chanDim = -1

				# CONV => RELU => BN => POOL
				model.add(Conv2D(8, (5, 5), padding="same", input_shape=inputShape))
				model.add(Activation("relu"))
				model.add(BatchNormalization(axis=chanDim))
				model.add(MaxPooling2D(pool_size=(2, 2)))

				# first set of (CONV => RELU => BN) * 2 => POOL
				model.add(Conv2D(16, (3, 3), padding="same"))
				model.add(Activation("relu"))
				model.add(BatchNormalization(axis=chanDim))
				model.add(Conv2D(16, (3, 3), padding="same"))
				model.add(Activation("relu"))
				model.add(BatchNormalization(axis=chanDim))
				model.add(MaxPooling2D(pool_size=(2, 2)))

				# second set of (CONV => RELU => BN) * 2 => POOL
				model.add(Conv2D(32, (3, 3), padding="same"))
				model.add(Activation("relu"))
				model.add(BatchNormalization(axis=chanDim))
				model.add(Conv2D(32, (3, 3), padding="same"))
				model.add(Activation("relu"))
				model.add(BatchNormalization(axis=chanDim))
				model.add(MaxPooling2D(pool_size=(2, 2)))

				# freshly added set of (CONV => RELU => BN) * 2 => POOL
				model.add(Conv2D(64, (3, 3), padding="same"))
				model.add(Activation("relu"))
				model.add(BatchNormalization(axis=chanDim))
				model.add(Conv2D(64, (3, 3), padding="same"))
				model.add(Activation("relu"))
				model.add(BatchNormalization(axis=chanDim))
				model.add(MaxPooling2D(pool_size=(2, 2)))

				# first set of FC => RELU => BN layers
				model.add(Flatten())
				model.add(Dense(128))
				model.add(Activation("relu"))
				model.add(BatchNormalization())
				model.add(Dropout(0.5))

				# second set of FC => RELU => BN layers
				model.add(Flatten())
				model.add(Dense(128))
				model.add(Activation("relu"))
				model.add(BatchNormalization())
				model.add(Dropout(0.5))

				# softmax classifier
				model.add(Dense(classes))
				model.add(Activation("softmax"))

				return model

print("[INFO] Model created!")
# Out:
# [INFO] Model created!

# %%
# funkcja do przygotowania obrazów
def load_split(basePath, csvPath):
    # inicjalizacja list dla danych i etykiet (klas znaków)
    data = []
    labels = []

	  # wczytanie zawartości pliku CSV z opisem danych, z pominięciem pierwszej linii
    rows = open(csvPath).read().strip().split("\n")[1:]

    # wymieszanie przykładów uczących
    random.shuffle(rows)

    # pętla po przykładach uczących
    for (i, row) in enumerate(rows):
	      # wypisanie informacji co 1000 przykładów
        if i > 0 and i % 1000 == 0:
           print("[INFO] processed {} total images.".format(i))

        # dla danego rzędu pozyskujemy etykietę (label) oraz ścieżkę do pliku
        (label, imagePath) = row.strip().split(",")[-2:]

	  	  # "skompletowanie" ścieżki i wczytanie obrazu
        imagePath = os.path.sep.join([basePath, imagePath])
        image = io.imread(imagePath)

        # przeskalowanie do rozmiaru 32x32 i poprawa kontrastu metodą CLAHE (Contrast Limited Adaptive Histogram Equalization)
        image = transform.resize(image, (32, 32))
        image = exposure.equalize_adapthist(image, clip_limit=0.1)

        # dodanie obrazka i etykiet do listy
        data.append(image)
        labels.append(int(label))

    # konwersja danych i etykiet na tablice NumPy
    data = np.array(data)
    labels = np.array(labels)

	  # zwracamy dane i etykiety (w formie krotki)
    return (data, labels)

print("[INFO] Function defined.")
# Out:
# [INFO] Function defined.

# %%
# !pip3 install --upgrade gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.4.26)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# pobranie pliku z nazwami znaków
url = 'https://raw.githubusercontent.com/vision-agh/poc_sw/master/14_TSR_DCNN/'
fileNames = ["signnames.csv"]

for fileName in fileNames:
    if not os.path.exists(fileName):
        r = requests.get(url + fileName, allow_redirects=True)
        open(fileName, 'wb').write(r.content)

# Przygotowanie danych
# Jeśli ktoś używa Google Colab, należy:
# 1. Wgrać plik gtsrb.zip na dysk Google'a.
# 2. Podmontować dysk.

# from google.colab import drive

# drive.mount('/content/gdrive')

# !gdown 1b-ijBmRyyyL6ypu9Silp5RZz90sFc4VD&confirm=t

# 3. Zainstalować zip i rozpakować plik (uwaga, trzeba ustawić ścieżkę)
# !apt install unzip
# !unzip 'gtsrb.zip'

# Jeśli ktoś pracuje lokalnie, to trzeba tu ustawić ścieżkę do danych.
dataset = "gtsrb/"

# wczytanie nazw etykiet
labelNames = open("signnames.csv").read().strip().split("\n")[1:]
labelNames = [l.split(",")[0] for l in labelNames]

# ustawienie ścieżki do zbioru uczącego i testowego
trainPath = os.path.sep.join([dataset, "Train.csv"])
testPath = os.path.sep.join([dataset, "Test.csv"])

# wczytanie danych uczących i testowych (może dość długo trwać)
print("[INFO] loading training and testing data...")
(trainX, trainY) = load_split(dataset, trainPath)
(testX, testY) = load_split(dataset, testPath)

# przeskalowanie danych do zakresu [0; 1]
trainX = trainX.astype("float32") / 255.0
testX = testX.astype("float32") / 255.0

# Zakodowanie etykiet danych uczących i testowych w formacie one-hot-encoding (z całego wektora tylko jedna wartość to 1, reszta 0).
# To wprost koresponduje z wyjściem z sieci (warstwa softmax), gdzie otrzymujemy wektor długości takiej, ile mamy klas (tutaj: 43)
# i wyszukujemy w nim maksimum.

numLabels = len(np.unique(trainY))
trainY = to_categorical(trainY, numLabels)
testY = to_categorical(testY, numLabels)

# zapis danych uczących i testowych do pliku (żeby tego ewentualnie nie powtarzać), jak coś na dalszym etapie pójdzie nie tak
print("[INFO] saving training and testing data...")

with open('train_test.pickle', 'wb') as f:
    pickle.dump([trainX, trainY, testX, testY], f)
# Out:
# Strumieniowane dane wyjściowe obcięte do 5000 ostatnich wierszy.
#   inflating: gtsrb/train/27/00027_00003_00013.png
#   inflating: gtsrb/train/27/00027_00003_00014.png
#   inflating: gtsrb/train/27/00027_00003_00015.png
#   inflating: gtsrb/train/27/00027_00003_00016.png
#   inflating: gtsrb/train/27/00027_00003_00017.png
#   inflating: gtsrb/train/27/00027_00003_00018.png
#   inflating: gtsrb/train/27/00027_00003_00019.png
#   inflating: gtsrb/train/27/00027_00003_00020.png
#   inflating: gtsrb/train/27/00027_00003_00021.png
#   inflating: gtsrb/train/27/00027_00003_00022.png
#   inflating: gtsrb/train/27/00027_00003_00023.png
#   inflating: gtsrb/train/27/00027_00003_00024.png
#   inflating: gtsrb/train/27/00027_00003_00025.png
#   inflating: gtsrb/train/27/00027_00003_00026.png
#   inflating: gtsrb/train/27/00027_00003_00027.png
#   inflating: gtsrb/train/27/00027_00003_00028.png
#   inflating: gtsrb/train/27/00027_00003_00029.png
#   inflating: gtsrb/train/27/00027_00004_00000.png
#   inflating: gtsrb/train/27/00027_00004_00001.png
#   inflating: gtsrb/train/27/00027_00004_00002.png
#   inflating: gtsrb/train/27/00027_00004_00003.png
#   inflating: gtsrb/train/27/00027_00004_00004.png
#   inflating: gtsrb/train/27/00027_00004_00005.png
#   inflating: gtsrb/train/27/00027_00004_00006.png
#   inflating: gtsrb/train/27/00027_00004_00007.png
#   inflating: gtsrb/train/27/00027_00004_00008.png
#   inflating: gtsrb/train/27/00027_00004_00009.png
#   inflating: gtsrb/train/27/00027_00004_00010.png
#   inflating: gtsrb/train/27/00027_00004_00011.png
#   inflating: gtsrb/train/27/00027_00004_00012.png
#   inflating: gtsrb/train/27/00027_00004_00013.png
#   inflating: gtsrb/train/27/00027_00004_00014.png
#   inflating: gtsrb/train/27/00027_00004_00015.png
#   inflating: gtsrb/train/27/00027_00004_00016.png
#   inflating: gtsrb/train/27/00027_00004_00017.png
#   inflating: gtsrb/train/27/00027_00004_00018.png
#   inflating: gtsrb/train/27/00027_00004_00019.png
#   inflating: gtsrb/train/27/00027_00004_00020.png
#   inflating: gtsrb/train/27/00027_00004_00021.png
#   inflating: gtsrb/train/27/00027_00004_00022.png
#   inflating: gtsrb/train/27/00027_00004_00023.png
#   inflating: gtsrb/train/27/00027_00004_00024.png
#   inflating: gtsrb/train/27/00027_00004_00025.png
#   inflating: gtsrb/train/27/00027_00004_00026.png
#   inflating: gtsrb/train/27/00027_00004_00027.png
#   inflating: gtsrb/train/27/00027_00004_00028.png
#   inflating: gtsrb/train/27/00027_00004_00029.png
#   inflating: gtsrb/train/27/00027_00005_00000.png
#   inflating: gtsrb/train/27/00027_00005_00001.png
#   inflating: gtsrb/train/27/00027_00005_00002.png
#   inflating: gtsrb/train/27/00027_00005_00003.png
#   inflating: gtsrb/train/27/00027_00005_00004.png
#   inflating: gtsrb/train/27/00027_00005_00005.png
#   inflating: gtsrb/train/27/00027_00005_00006.png
#   inflating: gtsrb/train/27/00027_00005_00007.png
#   inflating: gtsrb/train/27/00027_00005_00008.png
#   inflating: gtsrb/train/27/00027_00005_00009.png
#   inflating: gtsrb/train/27/00027_00005_00010.png
#   inflating: gtsrb/train/27/00027_00005_00011.png
#   inflating: gtsrb/train/27/00027_00005_00012.png
#   inflating: gtsrb/train/27/00027_00005_00013.png
#   inflating: gtsrb/train/27/00027_00005_00014.png
#   inflating: gtsrb/train/27/00027_00005_00015.png
#   inflating: gtsrb/train/27/00027_00005_00016.png
#   inflating: gtsrb/train/27/00027_00005_00017.png
#   inflating: gtsrb/train/27/00027_00005_00018.png
#   inflating: gtsrb/train/27/00027_00005_00019.png
#   inflating: gtsrb/train/27/00027_00005_00020.png
#   inflating: gtsrb/train/27/00027_00005_00021.png
#   inflating: gtsrb/train/27/00027_00005_00022.png
#   inflating: gtsrb/train/27/00027_00005_00023.png
#   inflating: gtsrb/train/27/00027_00005_00024.png
#   inflating: gtsrb/train/27/00027_00005_00025.png
#   inflating: gtsrb/train/27/00027_00005_00026.png
#   inflating: gtsrb/train/27/00027_00005_00027.png
#   inflating: gtsrb/train/27/00027_00005_00028.png
#   inflating: gtsrb/train/27/00027_00005_00029.png
#   inflating: gtsrb/train/27/00027_00006_00000.png
#   inflating: gtsrb/train/27/00027_00006_00001.png
#   inflating: gtsrb/train/27/00027_00006_00002.png
#   inflating: gtsrb/train/27/00027_00006_00003.png
#   inflating: gtsrb/train/27/00027_00006_00004.png
#   inflating: gtsrb/train/27/00027_00006_00005.png
#   inflating: gtsrb/train/27/00027_00006_00006.png
#   inflating: gtsrb/train/27/00027_00006_00007.png
#   inflating: gtsrb/train/27/00027_00006_00008.png
#   inflating: gtsrb/train/27/00027_00006_00009.png
#   inflating: gtsrb/train/27/00027_00006_00010.png
#   inflating: gtsrb/train/27/00027_00006_00011.png
#   inflating: gtsrb/train/27/00027_00006_00012.png
#   inflating: gtsrb/train/27/00027_00006_00013.png
#   inflating: gtsrb/train/27/00027_00006_00014.png
#   inflating: gtsrb/train/27/00027_00006_00015.png
#   inflating: gtsrb/train/27/00027_00006_00016.png
#   inflating: gtsrb/train/27/00027_00006_00017.png
#   inflating: gtsrb/train/27/00027_00006_00018.png
#   inflating: gtsrb/train/27/00027_00006_00019.png
#   inflating: gtsrb/train/27/00027_00006_00020.png
#   inflating: gtsrb/train/27/00027_00006_00021.png
#   inflating: gtsrb/train/27/00027_00006_00022.png
#   inflating: gtsrb/train/27/00027_00006_00023.png
#   inflating: gtsrb/train/27/00027_00006_00024.png
#   inflating: gtsrb/train/27/00027_00006_00025.png
#   inflating: gtsrb/train/27/00027_00006_00026.png
#   inflating: gtsrb/train/27/00027_00006_00027.png
#   inflating: gtsrb/train/27/00027_00006_00028.png
#   inflating: gtsrb/train/27/00027_00006_00029.png
#   inflating: gtsrb/train/27/00027_00007_00000.png
#   inflating: gtsrb/train/27/00027_00007_00001.png
#   inflating: gtsrb/train/27/00027_00007_00002.png
#   inflating: gtsrb/train/27/00027_00007_00003.png
#   inflating: gtsrb/train/27/00027_00007_00004.png
#   inflating: gtsrb/train/27/00027_00007_00005.png
#   inflating: gtsrb/train/27/00027_00007_00006.png
#   inflating: gtsrb/train/27/00027_00007_00007.png
#   inflating: gtsrb/train/27/00027_00007_00008.png
#   inflating: gtsrb/train/27/00027_00007_00009.png
#   inflating: gtsrb/train/27/00027_00007_00010.png
#   inflating: gtsrb/train/27/00027_00007_00011.png
#   inflating: gtsrb/train/27/00027_00007_00012.png
#   inflating: gtsrb/train/27/00027_00007_00013.png
#   inflating: gtsrb/train/27/00027_00007_00014.png
#   inflating: gtsrb/train/27/00027_00007_00015.png
#   inflating: gtsrb/train/27/00027_00007_00016.png
#   inflating: gtsrb/train/27/00027_00007_00017.png
#   inflating: gtsrb/train/27/00027_00007_00018.png
#   inflating: gtsrb/train/27/00027_00007_00019.png
#   inflating: gtsrb/train/27/00027_00007_00020.png
#   inflating: gtsrb/train/27/00027_00007_00021.png
#   inflating: gtsrb/train/27/00027_00007_00022.png
#   inflating: gtsrb/train/27/00027_00007_00023.png
#   inflating: gtsrb/train/27/00027_00007_00024.png
#   inflating: gtsrb/train/27/00027_00007_00025.png
#   inflating: gtsrb/train/27/00027_00007_00026.png
#   inflating: gtsrb/train/27/00027_00007_00027.png
#   inflating: gtsrb/train/27/00027_00007_00028.png
#   inflating: gtsrb/train/27/00027_00007_00029.png
#    creating: gtsrb/train/37/
#   inflating: gtsrb/train/37/00037_00000_00000.png
#   inflating: gtsrb/train/37/00037_00000_00001.png
#   inflating: gtsrb/train/37/00037_00000_00002.png
#   inflating: gtsrb/train/37/00037_00000_00003.png
#   inflating: gtsrb/train/37/00037_00000_00004.png
#   inflating: gtsrb/train/37/00037_00000_00005.png
#   inflating: gtsrb/train/37/00037_00000_00006.png
#   inflating: gtsrb/train/37/00037_00000_00007.png
#   inflating: gtsrb/train/37/00037_00000_00008.png
#   inflating: gtsrb/train/37/00037_00000_00009.png
#   inflating: gtsrb/train/37/00037_00000_00010.png
#   inflating: gtsrb/train/37/00037_00000_00011.png
#   inflating: gtsrb/train/37/00037_00000_00012.png
#   inflating: gtsrb/train/37/00037_00000_00013.png
#   inflating: gtsrb/train/37/00037_00000_00014.png
#   inflating: gtsrb/train/37/00037_00000_00015.png
#   inflating: gtsrb/train/37/00037_00000_00016.png
#   inflating: gtsrb/train/37/00037_00000_00017.png
#   inflating: gtsrb/train/37/00037_00000_00018.png
#   inflating: gtsrb/train/37/00037_00000_00019.png
#   inflating: gtsrb/train/37/00037_00000_00020.png
#   inflating: gtsrb/train/37/00037_00000_00021.png
#   inflating: gtsrb/train/37/00037_00000_00022.png
#   inflating: gtsrb/train/37/00037_00000_00023.png
#   inflating: gtsrb/train/37/00037_00000_00024.png
#   inflating: gtsrb/train/37/00037_00000_00025.png
#   inflating: gtsrb/train/37/00037_00000_00026.png
#   inflating: gtsrb/train/37/00037_00000_00027.png
#   inflating: gtsrb/train/37/00037_00000_00028.png
#   inflating: gtsrb/train/37/00037_00000_00029.png
#   inflating: gtsrb/train/37/00037_00001_00000.png
#   inflating: gtsrb/train/37/00037_00001_00001.png
#   inflating: gtsrb/train/37/00037_00001_00002.png
#   inflating: gtsrb/train/37/00037_00001_00003.png
#   inflating: gtsrb/train/37/00037_00001_00004.png
#   inflating: gtsrb/train/37/00037_00001_00005.png
#   inflating: gtsrb/train/37/00037_00001_00006.png
#   inflating: gtsrb/train/37/00037_00001_00007.png
#   inflating: gtsrb/train/37/00037_00001_00008.png
#   inflating: gtsrb/train/37/00037_00001_00009.png
#   inflating: gtsrb/train/37/00037_00001_00010.png
#   inflating: gtsrb/train/37/00037_00001_00011.png
#   inflating: gtsrb/train/37/00037_00001_00012.png
#   inflating: gtsrb/train/37/00037_00001_00013.png
#   inflating: gtsrb/train/37/00037_00001_00014.png
#   inflating: gtsrb/train/37/00037_00001_00015.png
#   inflating: gtsrb/train/37/00037_00001_00016.png
#   inflating: gtsrb/train/37/00037_00001_00017.png
#   inflating: gtsrb/train/37/00037_00001_00018.png
#   inflating: gtsrb/train/37/00037_00001_00019.png
#   inflating: gtsrb/train/37/00037_00001_00020.png
#   inflating: gtsrb/train/37/00037_00001_00021.png
#   inflating: gtsrb/train/37/00037_00001_00022.png
#   inflating: gtsrb/train/37/00037_00001_00023.png
#   inflating: gtsrb/train/37/00037_00001_00024.png
#   inflating: gtsrb/train/37/00037_00001_00025.png
#   inflating: gtsrb/train/37/00037_00001_00026.png
#   inflating: gtsrb/train/37/00037_00001_00027.png
#   inflating: gtsrb/train/37/00037_00001_00028.png
#   inflating: gtsrb/train/37/00037_00001_00029.png
#   inflating: gtsrb/train/37/00037_00002_00000.png
#   inflating: gtsrb/train/37/00037_00002_00001.png
#   inflating: gtsrb/train/37/00037_00002_00002.png
#   inflating: gtsrb/train/37/00037_00002_00003.png
#   inflating: gtsrb/train/37/00037_00002_00004.png
#   inflating: gtsrb/train/37/00037_00002_00005.png
#   inflating: gtsrb/train/37/00037_00002_00006.png
#   inflating: gtsrb/train/37/00037_00002_00007.png
#   inflating: gtsrb/train/37/00037_00002_00008.png
#   inflating: gtsrb/train/37/00037_00002_00009.png
#   inflating: gtsrb/train/37/00037_00002_00010.png
#   inflating: gtsrb/train/37/00037_00002_00011.png
#   inflating: gtsrb/train/37/00037_00002_00012.png
#   inflating: gtsrb/train/37/00037_00002_00013.png
#   inflating: gtsrb/train/37/00037_00002_00014.png
#   inflating: gtsrb/train/37/00037_00002_00015.png
#   inflating: gtsrb/train/37/00037_00002_00016.png
#   inflating: gtsrb/train/37/00037_00002_00017.png
#   inflating: gtsrb/train/37/00037_00002_00018.png
#   inflating: gtsrb/train/37/00037_00002_00019.png
#   inflating: gtsrb/train/37/00037_00002_00020.png
#   inflating: gtsrb/train/37/00037_00002_00021.png
#   inflating: gtsrb/train/37/00037_00002_00022.png
#   inflating: gtsrb/train/37/00037_00002_00023.png
#   inflating: gtsrb/train/37/00037_00002_00024.png
#   inflating: gtsrb/train/37/00037_00002_00025.png
#   inflating: gtsrb/train/37/00037_00002_00026.png
#   inflating: gtsrb/train/37/00037_00002_00027.png
#   inflating: gtsrb/train/37/00037_00002_00028.png
#   inflating: gtsrb/train/37/00037_00002_00029.png
#   inflating: gtsrb/train/37/00037_00003_00000.png
#   inflating: gtsrb/train/37/00037_00003_00001.png
#   inflating: gtsrb/train/37/00037_00003_00002.png
#   inflating: gtsrb/train/37/00037_00003_00003.png
#   inflating: gtsrb/train/37/00037_00003_00004.png
#   inflating: gtsrb/train/37/00037_00003_00005.png
#   inflating: gtsrb/train/37/00037_00003_00006.png
#   inflating: gtsrb/train/37/00037_00003_00007.png
#   inflating: gtsrb/train/37/00037_00003_00008.png
#   inflating: gtsrb/train/37/00037_00003_00009.png
#   inflating: gtsrb/train/37/00037_00003_00010.png
#   inflating: gtsrb/train/37/00037_00003_00011.png
#   inflating: gtsrb/train/37/00037_00003_00012.png
#   inflating: gtsrb/train/37/00037_00003_00013.png
#   inflating: gtsrb/train/37/00037_00003_00014.png
#   inflating: gtsrb/train/37/00037_00003_00015.png
#   inflating: gtsrb/train/37/00037_00003_00016.png
#   inflating: gtsrb/train/37/00037_00003_00017.png
#   inflating: gtsrb/train/37/00037_00003_00018.png
#   inflating: gtsrb/train/37/00037_00003_00019.png
#   inflating: gtsrb/train/37/00037_00003_00020.png
#   inflating: gtsrb/train/37/00037_00003_00021.png
#   inflating: gtsrb/train/37/00037_00003_00022.png
#   inflating: gtsrb/train/37/00037_00003_00023.png
#   inflating: gtsrb/train/37/00037_00003_00024.png
#   inflating: gtsrb/train/37/00037_00003_00025.png
#   inflating: gtsrb/train/37/00037_00003_00026.png
#   inflating: gtsrb/train/37/00037_00003_00027.png
#   inflating: gtsrb/train/37/00037_00003_00028.png
#   inflating: gtsrb/train/37/00037_00003_00029.png
#   inflating: gtsrb/train/37/00037_00004_00000.png
#   inflating: gtsrb/train/37/00037_00004_00001.png
#   inflating: gtsrb/train/37/00037_00004_00002.png
#   inflating: gtsrb/train/37/00037_00004_00003.png
#   inflating: gtsrb/train/37/00037_00004_00004.png
#   inflating: gtsrb/train/37/00037_00004_00005.png
#   inflating: gtsrb/train/37/00037_00004_00006.png
#   inflating: gtsrb/train/37/00037_00004_00007.png
#   inflating: gtsrb/train/37/00037_00004_00008.png
#   inflating: gtsrb/train/37/00037_00004_00009.png
#   inflating: gtsrb/train/37/00037_00004_00010.png
#   inflating: gtsrb/train/37/00037_00004_00011.png
#   inflating: gtsrb/train/37/00037_00004_00012.png
#   inflating: gtsrb/train/37/00037_00004_00013.png
#   inflating: gtsrb/train/37/00037_00004_00014.png
#   inflating: gtsrb/train/37/00037_00004_00015.png
#   inflating: gtsrb/train/37/00037_00004_00016.png
#   inflating: gtsrb/train/37/00037_00004_00017.png
#   inflating: gtsrb/train/37/00037_00004_00018.png
#   inflating: gtsrb/train/37/00037_00004_00019.png
#   inflating: gtsrb/train/37/00037_00004_00020.png
#   inflating: gtsrb/train/37/00037_00004_00021.png
#   inflating: gtsrb/train/37/00037_00004_00022.png
#   inflating: gtsrb/train/37/00037_00004_00023.png
#   inflating: gtsrb/train/37/00037_00004_00024.png
#   inflating: gtsrb/train/37/00037_00004_00025.png
#   inflating: gtsrb/train/37/00037_00004_00026.png
#   inflating: gtsrb/train/37/00037_00004_00027.png
#   inflating: gtsrb/train/37/00037_00004_00028.png
#   inflating: gtsrb/train/37/00037_00004_00029.png
#   inflating: gtsrb/train/37/00037_00005_00000.png
#   inflating: gtsrb/train/37/00037_00005_00001.png
#   inflating: gtsrb/train/37/00037_00005_00002.png
#   inflating: gtsrb/train/37/00037_00005_00003.png
#   inflating: gtsrb/train/37/00037_00005_00004.png
#   inflating: gtsrb/train/37/00037_00005_00005.png
#   inflating: gtsrb/train/37/00037_00005_00006.png
#   inflating: gtsrb/train/37/00037_00005_00007.png
#   inflating: gtsrb/train/37/00037_00005_00008.png
#   inflating: gtsrb/train/37/00037_00005_00009.png
#   inflating: gtsrb/train/37/00037_00005_00010.png
#   inflating: gtsrb/train/37/00037_00005_00011.png
#   inflating: gtsrb/train/37/00037_00005_00012.png
#   inflating: gtsrb/train/37/00037_00005_00013.png
#   inflating: gtsrb/train/37/00037_00005_00014.png
#   inflating: gtsrb/train/37/00037_00005_00015.png
#   inflating: gtsrb/train/37/00037_00005_00016.png
#   inflating: gtsrb/train/37/00037_00005_00017.png
#   inflating: gtsrb/train/37/00037_00005_00018.png
#   inflating: gtsrb/train/37/00037_00005_00019.png
#   inflating: gtsrb/train/37/00037_00005_00020.png
#   inflating: gtsrb/train/37/00037_00005_00021.png
#   inflating: gtsrb/train/37/00037_00005_00022.png
#   inflating: gtsrb/train/37/00037_00005_00023.png
#   inflating: gtsrb/train/37/00037_00005_00024.png
#   inflating: gtsrb/train/37/00037_00005_00025.png
#   inflating: gtsrb/train/37/00037_00005_00026.png
#   inflating: gtsrb/train/37/00037_00005_00027.png
#   inflating: gtsrb/train/37/00037_00005_00028.png
#   inflating: gtsrb/train/37/00037_00005_00029.png
#   inflating: gtsrb/train/37/00037_00006_00000.png
#   inflating: gtsrb/train/37/00037_00006_00001.png
#   inflating: gtsrb/train/37/00037_00006_00002.png
#   inflating: gtsrb/train/37/00037_00006_00003.png
#   inflating: gtsrb/train/37/00037_00006_00004.png
#   inflating: gtsrb/train/37/00037_00006_00005.png
#   inflating: gtsrb/train/37/00037_00006_00006.png
#   inflating: gtsrb/train/37/00037_00006_00007.png
#   inflating: gtsrb/train/37/00037_00006_00008.png
#   inflating: gtsrb/train/37/00037_00006_00009.png
#   inflating: gtsrb/train/37/00037_00006_00010.png
#   inflating: gtsrb/train/37/00037_00006_00011.png
#   inflating: gtsrb/train/37/00037_00006_00012.png
#   inflating: gtsrb/train/37/00037_00006_00013.png
#   inflating: gtsrb/train/37/00037_00006_00014.png
#   inflating: gtsrb/train/37/00037_00006_00015.png
#   inflating: gtsrb/train/37/00037_00006_00016.png
#   inflating: gtsrb/train/37/00037_00006_00017.png
#   inflating: gtsrb/train/37/00037_00006_00018.png
#   inflating: gtsrb/train/37/00037_00006_00019.png
#   inflating: gtsrb/train/37/00037_00006_00020.png
#   inflating: gtsrb/train/37/00037_00006_00021.png
#   inflating: gtsrb/train/37/00037_00006_00022.png
#   inflating: gtsrb/train/37/00037_00006_00023.png
#   inflating: gtsrb/train/37/00037_00006_00024.png
#   inflating: gtsrb/train/37/00037_00006_00025.png
#   inflating: gtsrb/train/37/00037_00006_00026.png
#   inflating: gtsrb/train/37/00037_00006_00027.png
#   inflating: gtsrb/train/37/00037_00006_00028.png
#   inflating: gtsrb/train/37/00037_00006_00029.png
#    creating: gtsrb/train/18/
#   inflating: gtsrb/train/18/00018_00000_00000.png
#   inflating: gtsrb/train/18/00018_00000_00001.png
#   inflating: gtsrb/train/18/00018_00000_00002.png
#   inflating: gtsrb/train/18/00018_00000_00003.png
#   inflating: gtsrb/train/18/00018_00000_00004.png
#   inflating: gtsrb/train/18/00018_00000_00005.png
#   inflating: gtsrb/train/18/00018_00000_00006.png
#   inflating: gtsrb/train/18/00018_00000_00009.png
#   inflating: gtsrb/train/18/00018_00000_00010.png
#   inflating: gtsrb/train/18/00018_00000_00011.png
#   inflating: gtsrb/train/18/00018_00000_00012.png
#   inflating: gtsrb/train/18/00018_00000_00013.png
#   inflating: gtsrb/train/18/00018_00000_00015.png
#   inflating: gtsrb/train/18/00018_00000_00016.png
#   inflating: gtsrb/train/18/00018_00000_00017.png
#   inflating: gtsrb/train/18/00018_00000_00018.png
#   inflating: gtsrb/train/18/00018_00000_00019.png
#   inflating: gtsrb/train/18/00018_00000_00020.png
#   inflating: gtsrb/train/18/00018_00000_00021.png
#   inflating: gtsrb/train/18/00018_00000_00022.png
#   inflating: gtsrb/train/18/00018_00000_00023.png
#   inflating: gtsrb/train/18/00018_00000_00024.png
#   inflating: gtsrb/train/18/00018_00000_00026.png
#   inflating: gtsrb/train/18/00018_00000_00027.png
#   inflating: gtsrb/train/18/00018_00000_00028.png
#   inflating: gtsrb/train/18/00018_00001_00000.png
#   inflating: gtsrb/train/18/00018_00001_00001.png
#   inflating: gtsrb/train/18/00018_00001_00002.png
#   inflating: gtsrb/train/18/00018_00001_00004.png
#   inflating: gtsrb/train/18/00018_00001_00005.png
#   inflating: gtsrb/train/18/00018_00001_00006.png
#   inflating: gtsrb/train/18/00018_00001_00007.png
#   inflating: gtsrb/train/18/00018_00001_00008.png
#   inflating: gtsrb/train/18/00018_00001_00009.png
#   inflating: gtsrb/train/18/00018_00001_00010.png
#   inflating: gtsrb/train/18/00018_00001_00011.png
#   inflating: gtsrb/train/18/00018_00001_00012.png
#   inflating: gtsrb/train/18/00018_00001_00013.png
#   inflating: gtsrb/train/18/00018_00001_00014.png
#   inflating: gtsrb/train/18/00018_00001_00015.png
#   inflating: gtsrb/train/18/00018_00001_00016.png
#   inflating: gtsrb/train/18/00018_00001_00017.png
#   inflating: gtsrb/train/18/00018_00001_00020.png
#   inflating: gtsrb/train/18/00018_00001_00021.png
#   inflating: gtsrb/train/18/00018_00001_00022.png
#   inflating: gtsrb/train/18/00018_00001_00023.png
#   inflating: gtsrb/train/18/00018_00001_00024.png
#   inflating: gtsrb/train/18/00018_00001_00025.png
#   inflating: gtsrb/train/18/00018_00001_00026.png
#   inflating: gtsrb/train/18/00018_00001_00027.png
#   inflating: gtsrb/train/18/00018_00001_00028.png
#   inflating: gtsrb/train/18/00018_00002_00000.png
#   inflating: gtsrb/train/18/00018_00002_00001.png
#   inflating: gtsrb/train/18/00018_00002_00002.png
#   inflating: gtsrb/train/18/00018_00002_00003.png
#   inflating: gtsrb/train/18/00018_00002_00004.png
#   inflating: gtsrb/train/18/00018_00002_00006.png
#   inflating: gtsrb/train/18/00018_00002_00007.png
#   inflating: gtsrb/train/18/00018_00002_00008.png
#   inflating: gtsrb/train/18/00018_00002_00009.png
#   inflating: gtsrb/train/18/00018_00002_00010.png
#   inflating: gtsrb/train/18/00018_00002_00011.png
#   inflating: gtsrb/train/18/00018_00002_00012.png
#   inflating: gtsrb/train/18/00018_00002_00013.png
#   inflating: gtsrb/train/18/00018_00002_00014.png
#   inflating: gtsrb/train/18/00018_00002_00015.png
#   inflating: gtsrb/train/18/00018_00002_00016.png
#   inflating: gtsrb/train/18/00018_00002_00017.png
#   inflating: gtsrb/train/18/00018_00002_00018.png
#   inflating: gtsrb/train/18/00018_00002_00019.png
#   inflating: gtsrb/train/18/00018_00002_00020.png
#   inflating: gtsrb/train/18/00018_00002_00021.png
#   inflating: gtsrb/train/18/00018_00002_00022.png
#   inflating: gtsrb/train/18/00018_00002_00023.png
#   inflating: gtsrb/train/18/00018_00002_00024.png
#   inflating: gtsrb/train/18/00018_00002_00025.png
#   inflating: gtsrb/train/18/00018_00002_00026.png
#   inflating: gtsrb/train/18/00018_00002_00027.png
#   inflating: gtsrb/train/18/00018_00002_00028.png
#   inflating: gtsrb/train/18/00018_00002_00029.png
#   inflating: gtsrb/train/18/00018_00003_00000.png
#   inflating: gtsrb/train/18/00018_00003_00001.png
#   inflating: gtsrb/train/18/00018_00003_00002.png
#   inflating: gtsrb/train/18/00018_00003_00003.png
#   inflating: gtsrb/train/18/00018_00003_00004.png
#   inflating: gtsrb/train/18/00018_00003_00005.png
#   inflating: gtsrb/train/18/00018_00003_00006.png
#   inflating: gtsrb/train/18/00018_00003_00007.png
#   inflating: gtsrb/train/18/00018_00003_00009.png
#   inflating: gtsrb/train/18/00018_00003_00010.png
#   inflating: gtsrb/train/18/00018_00003_00011.png
#   inflating: gtsrb/train/18/00018_00003_00012.png
#   inflating: gtsrb/train/18/00018_00003_00013.png
#   inflating: gtsrb/train/18/00018_00003_00015.png
#   inflating: gtsrb/train/18/00018_00003_00016.png
#   inflating: gtsrb/train/18/00018_00003_00017.png
#   inflating: gtsrb/train/18/00018_00003_00018.png
#   inflating: gtsrb/train/18/00018_00003_00019.png
#   inflating: gtsrb/train/18/00018_00003_00023.png
#   inflating: gtsrb/train/18/00018_00003_00024.png
#   inflating: gtsrb/train/18/00018_00003_00026.png
#   inflating: gtsrb/train/18/00018_00003_00027.png
#   inflating: gtsrb/train/18/00018_00004_00000.png
#   inflating: gtsrb/train/18/00018_00004_00001.png
#   inflating: gtsrb/train/18/00018_00004_00003.png
#   inflating: gtsrb/train/18/00018_00004_00006.png
#   inflating: gtsrb/train/18/00018_00004_00007.png
#   inflating: gtsrb/train/18/00018_00004_00008.png
#   inflating: gtsrb/train/18/00018_00004_00009.png
#   inflating: gtsrb/train/18/00018_00004_00010.png
#   inflating: gtsrb/train/18/00018_00004_00011.png
#   inflating: gtsrb/train/18/00018_00004_00012.png
#   inflating: gtsrb/train/18/00018_00004_00013.png
#   inflating: gtsrb/train/18/00018_00004_00014.png
#   inflating: gtsrb/train/18/00018_00004_00015.png
#   inflating: gtsrb/train/18/00018_00004_00016.png
#   inflating: gtsrb/train/18/00018_00004_00017.png
#   inflating: gtsrb/train/18/00018_00004_00019.png
#   inflating: gtsrb/train/18/00018_00004_00020.png
#   inflating: gtsrb/train/18/00018_00004_00022.png
#   inflating: gtsrb/train/18/00018_00004_00023.png
#   inflating: gtsrb/train/18/00018_00004_00025.png
#   inflating: gtsrb/train/18/00018_00004_00027.png
#   inflating: gtsrb/train/18/00018_00004_00028.png
#   inflating: gtsrb/train/18/00018_00004_00029.png
#   inflating: gtsrb/train/18/00018_00005_00000.png
#   inflating: gtsrb/train/18/00018_00005_00002.png
#   inflating: gtsrb/train/18/00018_00005_00003.png
#   inflating: gtsrb/train/18/00018_00005_00004.png
#   inflating: gtsrb/train/18/00018_00005_00005.png
#   inflating: gtsrb/train/18/00018_00005_00006.png
#   inflating: gtsrb/train/18/00018_00005_00007.png
#   inflating: gtsrb/train/18/00018_00005_00008.png
#   inflating: gtsrb/train/18/00018_00005_00009.png
#   inflating: gtsrb/train/18/00018_00005_00010.png
#   inflating: gtsrb/train/18/00018_00005_00012.png
#   inflating: gtsrb/train/18/00018_00005_00013.png
#   inflating: gtsrb/train/18/00018_00005_00014.png
#   inflating: gtsrb/train/18/00018_00005_00015.png
#   inflating: gtsrb/train/18/00018_00005_00017.png
#   inflating: gtsrb/train/18/00018_00005_00019.png
#   inflating: gtsrb/train/18/00018_00005_00020.png
#   inflating: gtsrb/train/18/00018_00005_00021.png
#   inflating: gtsrb/train/18/00018_00005_00022.png
#   inflating: gtsrb/train/18/00018_00005_00023.png
#   inflating: gtsrb/train/18/00018_00005_00024.png
#   inflating: gtsrb/train/18/00018_00005_00025.png
#   inflating: gtsrb/train/18/00018_00005_00026.png
#   inflating: gtsrb/train/18/00018_00005_00027.png
#   inflating: gtsrb/train/18/00018_00005_00028.png
#   inflating: gtsrb/train/18/00018_00005_00029.png
#   inflating: gtsrb/train/18/00018_00006_00001.png
#   inflating: gtsrb/train/18/00018_00006_00002.png
#   inflating: gtsrb/train/18/00018_00006_00003.png
#   inflating: gtsrb/train/18/00018_00006_00004.png
#   inflating: gtsrb/train/18/00018_00006_00005.png
#   inflating: gtsrb/train/18/00018_00006_00006.png
#   inflating: gtsrb/train/18/00018_00006_00007.png
#   inflating: gtsrb/train/18/00018_00006_00009.png
#   inflating: gtsrb/train/18/00018_00006_00010.png
#   inflating: gtsrb/train/18/00018_00006_00011.png
#   inflating: gtsrb/train/18/00018_00006_00012.png
#   inflating: gtsrb/train/18/00018_00006_00013.png
#   inflating: gtsrb/train/18/00018_00006_00014.png
#   inflating: gtsrb/train/18/00018_00006_00015.png
#   inflating: gtsrb/train/18/00018_00006_00016.png
#   inflating: gtsrb/train/18/00018_00006_00017.png
#   inflating: gtsrb/train/18/00018_00006_00018.png
#   inflating: gtsrb/train/18/00018_00006_00019.png
#   inflating: gtsrb/train/18/00018_00006_00020.png
#   inflating: gtsrb/train/18/00018_00006_00022.png
#   inflating: gtsrb/train/18/00018_00006_00024.png
#   inflating: gtsrb/train/18/00018_00006_00025.png
#   inflating: gtsrb/train/18/00018_00006_00026.png
#   inflating: gtsrb/train/18/00018_00006_00027.png
#   inflating: gtsrb/train/18/00018_00006_00028.png
#   inflating: gtsrb/train/18/00018_00007_00000.png
#   inflating: gtsrb/train/18/00018_00007_00001.png
#   inflating: gtsrb/train/18/00018_00007_00002.png
#   inflating: gtsrb/train/18/00018_00007_00003.png
#   inflating: gtsrb/train/18/00018_00007_00004.png
#   inflating: gtsrb/train/18/00018_00007_00007.png
#   inflating: gtsrb/train/18/00018_00007_00008.png
#   inflating: gtsrb/train/18/00018_00007_00009.png
#   inflating: gtsrb/train/18/00018_00007_00011.png
#   inflating: gtsrb/train/18/00018_00007_00013.png
#   inflating: gtsrb/train/18/00018_00007_00014.png
#   inflating: gtsrb/train/18/00018_00007_00015.png
#   inflating: gtsrb/train/18/00018_00007_00016.png
#   inflating: gtsrb/train/18/00018_00007_00018.png
#   inflating: gtsrb/train/18/00018_00007_00021.png
#   inflating: gtsrb/train/18/00018_00007_00022.png
#   inflating: gtsrb/train/18/00018_00007_00023.png
#   inflating: gtsrb/train/18/00018_00007_00024.png
#   inflating: gtsrb/train/18/00018_00007_00025.png
#   inflating: gtsrb/train/18/00018_00007_00026.png
#   inflating: gtsrb/train/18/00018_00007_00027.png
#   inflating: gtsrb/train/18/00018_00007_00029.png
#   inflating: gtsrb/train/18/00018_00008_00000.png
#   inflating: gtsrb/train/18/00018_00008_00001.png
#   inflating: gtsrb/train/18/00018_00008_00002.png
#   inflating: gtsrb/train/18/00018_00008_00003.png
#   inflating: gtsrb/train/18/00018_00008_00004.png
#   inflating: gtsrb/train/18/00018_00008_00005.png
#   inflating: gtsrb/train/18/00018_00008_00006.png
#   inflating: gtsrb/train/18/00018_00008_00007.png
#   inflating: gtsrb/train/18/00018_00008_00008.png
#   inflating: gtsrb/train/18/00018_00008_00009.png
#   inflating: gtsrb/train/18/00018_00008_00010.png
#   inflating: gtsrb/train/18/00018_00008_00011.png
#   inflating: gtsrb/train/18/00018_00008_00012.png
#   inflating: gtsrb/train/18/00018_00008_00013.png
#   inflating: gtsrb/train/18/00018_00008_00014.png
#   inflating: gtsrb/train/18/00018_00008_00015.png
#   inflating: gtsrb/train/18/00018_00008_00016.png
#   inflating: gtsrb/train/18/00018_00008_00017.png
#   inflating: gtsrb/train/18/00018_00008_00018.png
#   inflating: gtsrb/train/18/00018_00008_00019.png
#   inflating: gtsrb/train/18/00018_00008_00020.png
#   inflating: gtsrb/train/18/00018_00008_00021.png
#   inflating: gtsrb/train/18/00018_00008_00022.png
#   inflating: gtsrb/train/18/00018_00008_00023.png
#   inflating: gtsrb/train/18/00018_00008_00026.png
#   inflating: gtsrb/train/18/00018_00008_00027.png
#   inflating: gtsrb/train/18/00018_00008_00028.png
#   inflating: gtsrb/train/18/00018_00008_00029.png
#   inflating: gtsrb/train/18/00018_00009_00000.png
#   inflating: gtsrb/train/18/00018_00009_00001.png
#   inflating: gtsrb/train/18/00018_00009_00002.png
#   inflating: gtsrb/train/18/00018_00009_00003.png
#   inflating: gtsrb/train/18/00018_00009_00004.png
#   inflating: gtsrb/train/18/00018_00009_00006.png
#   inflating: gtsrb/train/18/00018_00009_00007.png
#   inflating: gtsrb/train/18/00018_00009_00009.png
#   inflating: gtsrb/train/18/00018_00009_00010.png
#   inflating: gtsrb/train/18/00018_00009_00011.png
#   inflating: gtsrb/train/18/00018_00009_00012.png
#   inflating: gtsrb/train/18/00018_00009_00013.png
#   inflating: gtsrb/train/18/00018_00009_00014.png
#   inflating: gtsrb/train/18/00018_00009_00015.png
#   inflating: gtsrb/train/18/00018_00009_00016.png
#   inflating: gtsrb/train/18/00018_00009_00017.png
#   inflating: gtsrb/train/18/00018_00009_00019.png
#   inflating: gtsrb/train/18/00018_00009_00020.png
#   inflating: gtsrb/train/18/00018_00009_00021.png
#   inflating: gtsrb/train/18/00018_00009_00023.png
#   inflating: gtsrb/train/18/00018_00009_00024.png
#   inflating: gtsrb/train/18/00018_00009_00025.png
#   inflating: gtsrb/train/18/00018_00009_00026.png
#   inflating: gtsrb/train/18/00018_00009_00027.png
#   inflating: gtsrb/train/18/00018_00009_00028.png
#   inflating: gtsrb/train/18/00018_00010_00001.png
#   inflating: gtsrb/train/18/00018_00010_00002.png
#   inflating: gtsrb/train/18/00018_00010_00004.png
#   inflating: gtsrb/train/18/00018_00010_00005.png
#   inflating: gtsrb/train/18/00018_00010_00006.png
#   inflating: gtsrb/train/18/00018_00010_00007.png
#   inflating: gtsrb/train/18/00018_00010_00009.png
#   inflating: gtsrb/train/18/00018_00010_00010.png
#   inflating: gtsrb/train/18/00018_00010_00011.png
#   inflating: gtsrb/train/18/00018_00010_00013.png
#   inflating: gtsrb/train/18/00018_00010_00014.png
#   inflating: gtsrb/train/18/00018_00010_00015.png
#   inflating: gtsrb/train/18/00018_00010_00016.png
#   inflating: gtsrb/train/18/00018_00010_00017.png
#   inflating: gtsrb/train/18/00018_00010_00018.png
#   inflating: gtsrb/train/18/00018_00010_00019.png
#   inflating: gtsrb/train/18/00018_00010_00020.png
#   inflating: gtsrb/train/18/00018_00010_00022.png
#   inflating: gtsrb/train/18/00018_00010_00023.png
#   inflating: gtsrb/train/18/00018_00010_00024.png
#   inflating: gtsrb/train/18/00018_00010_00025.png
#   inflating: gtsrb/train/18/00018_00010_00026.png
#   inflating: gtsrb/train/18/00018_00010_00027.png
#   inflating: gtsrb/train/18/00018_00010_00028.png
#   inflating: gtsrb/train/18/00018_00010_00029.png
#   inflating: gtsrb/train/18/00018_00011_00001.png
#   inflating: gtsrb/train/18/00018_00011_00002.png
#   inflating: gtsrb/train/18/00018_00011_00003.png
#   inflating: gtsrb/train/18/00018_00011_00004.png
#   inflating: gtsrb/train/18/00018_00011_00005.png
#   inflating: gtsrb/train/18/00018_00011_00008.png
#   inflating: gtsrb/train/18/00018_00011_00009.png
#   inflating: gtsrb/train/18/00018_00011_00011.png
#   inflating: gtsrb/train/18/00018_00011_00012.png
#   inflating: gtsrb/train/18/00018_00011_00013.png
#   inflating: gtsrb/train/18/00018_00011_00014.png
#   inflating: gtsrb/train/18/00018_00011_00015.png
#   inflating: gtsrb/train/18/00018_00011_00016.png
#   inflating: gtsrb/train/18/00018_00011_00017.png
#   inflating: gtsrb/train/18/00018_00011_00018.png
#   inflating: gtsrb/train/18/00018_00011_00020.png
#   inflating: gtsrb/train/18/00018_00011_00021.png
#   inflating: gtsrb/train/18/00018_00011_00022.png
#   inflating: gtsrb/train/18/00018_00011_00023.png
#   inflating: gtsrb/train/18/00018_00011_00024.png
#   inflating: gtsrb/train/18/00018_00011_00025.png
#   inflating: gtsrb/train/18/00018_00011_00027.png
#   inflating: gtsrb/train/18/00018_00011_00028.png
#   inflating: gtsrb/train/18/00018_00011_00029.png
#   inflating: gtsrb/train/18/00018_00012_00000.png
#   inflating: gtsrb/train/18/00018_00012_00001.png
#   inflating: gtsrb/train/18/00018_00012_00002.png
#   inflating: gtsrb/train/18/00018_00012_00003.png
#   inflating: gtsrb/train/18/00018_00012_00004.png
#   inflating: gtsrb/train/18/00018_00012_00005.png
#   inflating: gtsrb/train/18/00018_00012_00006.png
#   inflating: gtsrb/train/18/00018_00012_00007.png
#   inflating: gtsrb/train/18/00018_00012_00008.png
#   inflating: gtsrb/train/18/00018_00012_00009.png
#   inflating: gtsrb/train/18/00018_00012_00011.png
#   inflating: gtsrb/train/18/00018_00012_00012.png
#   inflating: gtsrb/train/18/00018_00012_00013.png
#   inflating: gtsrb/train/18/00018_00012_00014.png
#   inflating: gtsrb/train/18/00018_00012_00015.png
#   inflating: gtsrb/train/18/00018_00012_00016.png
#   inflating: gtsrb/train/18/00018_00012_00017.png
#   inflating: gtsrb/train/18/00018_00012_00018.png
#   inflating: gtsrb/train/18/00018_00012_00019.png
#   inflating: gtsrb/train/18/00018_00012_00022.png
#   inflating: gtsrb/train/18/00018_00012_00023.png
#   inflating: gtsrb/train/18/00018_00012_00024.png
#   inflating: gtsrb/train/18/00018_00012_00025.png
#   inflating: gtsrb/train/18/00018_00012_00027.png
#   inflating: gtsrb/train/18/00018_00012_00028.png
#   inflating: gtsrb/train/18/00018_00012_00029.png
#   inflating: gtsrb/train/18/00018_00013_00000.png
#   inflating: gtsrb/train/18/00018_00013_00001.png
#   inflating: gtsrb/train/18/00018_00013_00002.png
#   inflating: gtsrb/train/18/00018_00013_00003.png
#   inflating: gtsrb/train/18/00018_00013_00004.png
#   inflating: gtsrb/train/18/00018_00013_00005.png
#   inflating: gtsrb/train/18/00018_00013_00006.png
#   inflating: gtsrb/train/18/00018_00013_00007.png
#   inflating: gtsrb/train/18/00018_00013_00008.png
#   inflating: gtsrb/train/18/00018_00013_00009.png
#   inflating: gtsrb/train/18/00018_00013_00010.png
#   inflating: gtsrb/train/18/00018_00013_00011.png
#   inflating: gtsrb/train/18/00018_00013_00012.png
#   inflating: gtsrb/train/18/00018_00013_00013.png
#   inflating: gtsrb/train/18/00018_00013_00014.png
#   inflating: gtsrb/train/18/00018_00013_00016.png
#   inflating: gtsrb/train/18/00018_00013_00017.png
#   inflating: gtsrb/train/18/00018_00013_00019.png
#   inflating: gtsrb/train/18/00018_00013_00022.png
#   inflating: gtsrb/train/18/00018_00013_00023.png
#   inflating: gtsrb/train/18/00018_00013_00024.png
#   inflating: gtsrb/train/18/00018_00013_00026.png
#   inflating: gtsrb/train/18/00018_00013_00027.png
#   inflating: gtsrb/train/18/00018_00013_00028.png
#   inflating: gtsrb/train/18/00018_00013_00029.png
#   inflating: gtsrb/train/18/00018_00014_00001.png
#   inflating: gtsrb/train/18/00018_00014_00002.png
#   inflating: gtsrb/train/18/00018_00014_00004.png
#   inflating: gtsrb/train/18/00018_00014_00005.png
#   inflating: gtsrb/train/18/00018_00014_00006.png
#   inflating: gtsrb/train/18/00018_00014_00007.png
#   inflating: gtsrb/train/18/00018_00014_00008.png
#   inflating: gtsrb/train/18/00018_00014_00009.png
#   inflating: gtsrb/train/18/00018_00014_00010.png
#   inflating: gtsrb/train/18/00018_00014_00011.png
#   inflating: gtsrb/train/18/00018_00014_00012.png
#   inflating: gtsrb/train/18/00018_00014_00013.png
#   inflating: gtsrb/train/18/00018_00014_00014.png
#   inflating: gtsrb/train/18/00018_00014_00015.png
#   inflating: gtsrb/train/18/00018_00014_00018.png
#   inflating: gtsrb/train/18/00018_00014_00020.png
#   inflating: gtsrb/train/18/00018_00014_00022.png
#   inflating: gtsrb/train/18/00018_00014_00023.png
#   inflating: gtsrb/train/18/00018_00014_00024.png
#   inflating: gtsrb/train/18/00018_00014_00026.png
#   inflating: gtsrb/train/18/00018_00014_00027.png
#   inflating: gtsrb/train/18/00018_00014_00028.png
#   inflating: gtsrb/train/18/00018_00014_00029.png
#   inflating: gtsrb/train/18/00018_00015_00001.png
#   inflating: gtsrb/train/18/00018_00015_00002.png
#   inflating: gtsrb/train/18/00018_00015_00003.png
#   inflating: gtsrb/train/18/00018_00015_00004.png
#   inflating: gtsrb/train/18/00018_00015_00005.png
#   inflating: gtsrb/train/18/00018_00015_00006.png
#   inflating: gtsrb/train/18/00018_00015_00007.png
#   inflating: gtsrb/train/18/00018_00015_00009.png
#   inflating: gtsrb/train/18/00018_00015_00010.png
#   inflating: gtsrb/train/18/00018_00015_00011.png
#   inflating: gtsrb/train/18/00018_00015_00012.png
#   inflating: gtsrb/train/18/00018_00015_00013.png
#   inflating: gtsrb/train/18/00018_00015_00014.png
#   inflating: gtsrb/train/18/00018_00015_00015.png
#   inflating: gtsrb/train/18/00018_00015_00016.png
#   inflating: gtsrb/train/18/00018_00015_00017.png
#   inflating: gtsrb/train/18/00018_00015_00018.png
#   inflating: gtsrb/train/18/00018_00015_00019.png
#   inflating: gtsrb/train/18/00018_00015_00020.png
#   inflating: gtsrb/train/18/00018_00015_00021.png
#   inflating: gtsrb/train/18/00018_00015_00023.png
#   inflating: gtsrb/train/18/00018_00015_00025.png
#   inflating: gtsrb/train/18/00018_00015_00026.png
#   inflating: gtsrb/train/18/00018_00015_00029.png
#   inflating: gtsrb/train/18/00018_00016_00000.png
#   inflating: gtsrb/train/18/00018_00016_00001.png
#   inflating: gtsrb/train/18/00018_00016_00002.png
#   inflating: gtsrb/train/18/00018_00016_00003.png
#   inflating: gtsrb/train/18/00018_00016_00004.png
#   inflating: gtsrb/train/18/00018_00016_00005.png
#   inflating: gtsrb/train/18/00018_00016_00006.png
#   inflating: gtsrb/train/18/00018_00016_00007.png
#   inflating: gtsrb/train/18/00018_00016_00008.png
#   inflating: gtsrb/train/18/00018_00016_00009.png
#   inflating: gtsrb/train/18/00018_00016_00013.png
#   inflating: gtsrb/train/18/00018_00016_00015.png
#   inflating: gtsrb/train/18/00018_00016_00016.png
#   inflating: gtsrb/train/18/00018_00016_00017.png
#   inflating: gtsrb/train/18/00018_00016_00018.png
#   inflating: gtsrb/train/18/00018_00016_00019.png
#   inflating: gtsrb/train/18/00018_00016_00020.png
#   inflating: gtsrb/train/18/00018_00016_00021.png
#   inflating: gtsrb/train/18/00018_00016_00022.png
#   inflating: gtsrb/train/18/00018_00016_00023.png
#   inflating: gtsrb/train/18/00018_00016_00024.png
#   inflating: gtsrb/train/18/00018_00016_00025.png
#   inflating: gtsrb/train/18/00018_00016_00027.png
#   inflating: gtsrb/train/18/00018_00016_00028.png
#   inflating: gtsrb/train/18/00018_00016_00029.png
#   inflating: gtsrb/train/18/00018_00017_00000.png
#   inflating: gtsrb/train/18/00018_00017_00001.png
#   inflating: gtsrb/train/18/00018_00017_00002.png
#   inflating: gtsrb/train/18/00018_00017_00003.png
#   inflating: gtsrb/train/18/00018_00017_00004.png
#   inflating: gtsrb/train/18/00018_00017_00005.png
#   inflating: gtsrb/train/18/00018_00017_00006.png
#   inflating: gtsrb/train/18/00018_00017_00007.png
#   inflating: gtsrb/train/18/00018_00017_00008.png
#   inflating: gtsrb/train/18/00018_00017_00010.png
#   inflating: gtsrb/train/18/00018_00017_00013.png
#   inflating: gtsrb/train/18/00018_00017_00015.png
#   inflating: gtsrb/train/18/00018_00017_00016.png
#   inflating: gtsrb/train/18/00018_00017_00017.png
#   inflating: gtsrb/train/18/00018_00017_00018.png
#   inflating: gtsrb/train/18/00018_00017_00019.png
#   inflating: gtsrb/train/18/00018_00017_00021.png
#   inflating: gtsrb/train/18/00018_00017_00022.png
#   inflating: gtsrb/train/18/00018_00017_00023.png
#   inflating: gtsrb/train/18/00018_00017_00024.png
#   inflating: gtsrb/train/18/00018_00017_00025.png
#   inflating: gtsrb/train/18/00018_00017_00027.png
#   inflating: gtsrb/train/18/00018_00017_00028.png
#   inflating: gtsrb/train/18/00018_00017_00029.png
#   inflating: gtsrb/train/18/00018_00018_00001.png
#   inflating: gtsrb/train/18/00018_00018_00002.png
#   inflating: gtsrb/train/18/00018_00018_00003.png
#   inflating: gtsrb/train/18/00018_00018_00004.png
#   inflating: gtsrb/train/18/00018_00018_00005.png
#   inflating: gtsrb/train/18/00018_00018_00006.png
#   inflating: gtsrb/train/18/00018_00018_00007.png
#   inflating: gtsrb/train/18/00018_00018_00008.png
#   inflating: gtsrb/train/18/00018_00018_00009.png
#   inflating: gtsrb/train/18/00018_00018_00010.png
#   inflating: gtsrb/train/18/00018_00018_00011.png
#   inflating: gtsrb/train/18/00018_00018_00013.png
#   inflating: gtsrb/train/18/00018_00018_00014.png
#   inflating: gtsrb/train/18/00018_00018_00016.png
#   inflating: gtsrb/train/18/00018_00018_00017.png
#   inflating: gtsrb/train/18/00018_00018_00018.png
#   inflating: gtsrb/train/18/00018_00018_00019.png
#   inflating: gtsrb/train/18/00018_00018_00020.png
#   inflating: gtsrb/train/18/00018_00018_00021.png
#   inflating: gtsrb/train/18/00018_00018_00022.png
#   inflating: gtsrb/train/18/00018_00018_00023.png
#   inflating: gtsrb/train/18/00018_00018_00024.png
#   inflating: gtsrb/train/18/00018_00018_00025.png
#   inflating: gtsrb/train/18/00018_00018_00027.png
#   inflating: gtsrb/train/18/00018_00018_00028.png
#   inflating: gtsrb/train/18/00018_00018_00029.png
#   inflating: gtsrb/train/18/00018_00019_00001.png
#   inflating: gtsrb/train/18/00018_00019_00002.png
#   inflating: gtsrb/train/18/00018_00019_00003.png
#   inflating: gtsrb/train/18/00018_00019_00005.png
#   inflating: gtsrb/train/18/00018_00019_00006.png
#   inflating: gtsrb/train/18/00018_00019_00007.png
#   inflating: gtsrb/train/18/00018_00019_00008.png
#   inflating: gtsrb/train/18/00018_00019_00009.png
#   inflating: gtsrb/train/18/00018_00019_00010.png
#   inflating: gtsrb/train/18/00018_00019_00011.png
#   inflating: gtsrb/train/18/00018_00019_00012.png
#   inflating: gtsrb/train/18/00018_00019_00013.png
#   inflating: gtsrb/train/18/00018_00019_00014.png
#   inflating: gtsrb/train/18/00018_00019_00015.png
#   inflating: gtsrb/train/18/00018_00019_00016.png
#   inflating: gtsrb/train/18/00018_00019_00017.png
#   inflating: gtsrb/train/18/00018_00019_00018.png
#   inflating: gtsrb/train/18/00018_00019_00019.png
#   inflating: gtsrb/train/18/00018_00019_00020.png
#   inflating: gtsrb/train/18/00018_00019_00021.png
#   inflating: gtsrb/train/18/00018_00019_00022.png
#   inflating: gtsrb/train/18/00018_00019_00023.png
#   inflating: gtsrb/train/18/00018_00019_00024.png
#   inflating: gtsrb/train/18/00018_00019_00025.png
#   inflating: gtsrb/train/18/00018_00019_00026.png
#   inflating: gtsrb/train/18/00018_00019_00027.png
#   inflating: gtsrb/train/18/00018_00020_00000.png
#   inflating: gtsrb/train/18/00018_00020_00001.png
#   inflating: gtsrb/train/18/00018_00020_00002.png
#   inflating: gtsrb/train/18/00018_00020_00004.png
#   inflating: gtsrb/train/18/00018_00020_00005.png
#   inflating: gtsrb/train/18/00018_00020_00006.png
#   inflating: gtsrb/train/18/00018_00020_00007.png
#   inflating: gtsrb/train/18/00018_00020_00008.png
#   inflating: gtsrb/train/18/00018_00020_00009.png
#   inflating: gtsrb/train/18/00018_00020_00010.png
#   inflating: gtsrb/train/18/00018_00020_00012.png
#   inflating: gtsrb/train/18/00018_00020_00014.png
#   inflating: gtsrb/train/18/00018_00020_00015.png
#   inflating: gtsrb/train/18/00018_00020_00016.png
#   inflating: gtsrb/train/18/00018_00020_00017.png
#   inflating: gtsrb/train/18/00018_00020_00018.png
#   inflating: gtsrb/train/18/00018_00020_00019.png
#   inflating: gtsrb/train/18/00018_00020_00020.png
#   inflating: gtsrb/train/18/00018_00020_00021.png
#   inflating: gtsrb/train/18/00018_00020_00022.png
#   inflating: gtsrb/train/18/00018_00020_00023.png
#   inflating: gtsrb/train/18/00018_00020_00024.png
#   inflating: gtsrb/train/18/00018_00020_00025.png
#   inflating: gtsrb/train/18/00018_00020_00026.png
#   inflating: gtsrb/train/18/00018_00020_00027.png
#   inflating: gtsrb/train/18/00018_00020_00029.png
#   inflating: gtsrb/train/18/00018_00021_00000.png
#   inflating: gtsrb/train/18/00018_00021_00001.png
#   inflating: gtsrb/train/18/00018_00021_00003.png
#   inflating: gtsrb/train/18/00018_00021_00005.png
#   inflating: gtsrb/train/18/00018_00021_00007.png
#   inflating: gtsrb/train/18/00018_00021_00008.png
#   inflating: gtsrb/train/18/00018_00021_00009.png
#   inflating: gtsrb/train/18/00018_00021_00011.png
#   inflating: gtsrb/train/18/00018_00021_00014.png
#   inflating: gtsrb/train/18/00018_00021_00015.png
#   inflating: gtsrb/train/18/00018_00021_00016.png
#   inflating: gtsrb/train/18/00018_00021_00017.png
#   inflating: gtsrb/train/18/00018_00021_00018.png
#   inflating: gtsrb/train/18/00018_00021_00019.png
#   inflating: gtsrb/train/18/00018_00021_00020.png
#   inflating: gtsrb/train/18/00018_00021_00022.png
#   inflating: gtsrb/train/18/00018_00021_00023.png
#   inflating: gtsrb/train/18/00018_00021_00024.png
#   inflating: gtsrb/train/18/00018_00021_00025.png
#   inflating: gtsrb/train/18/00018_00021_00026.png
#   inflating: gtsrb/train/18/00018_00021_00027.png
#   inflating: gtsrb/train/18/00018_00021_00028.png
#   inflating: gtsrb/train/18/00018_00021_00029.png
#   inflating: gtsrb/train/18/00018_00022_00000.png
#   inflating: gtsrb/train/18/00018_00022_00001.png
#   inflating: gtsrb/train/18/00018_00022_00002.png
#   inflating: gtsrb/train/18/00018_00022_00003.png
#   inflating: gtsrb/train/18/00018_00022_00005.png
#   inflating: gtsrb/train/18/00018_00022_00006.png
#   inflating: gtsrb/train/18/00018_00022_00007.png
#   inflating: gtsrb/train/18/00018_00022_00010.png
#   inflating: gtsrb/train/18/00018_00022_00012.png
#   inflating: gtsrb/train/18/00018_00022_00013.png
#   inflating: gtsrb/train/18/00018_00022_00014.png
#   inflating: gtsrb/train/18/00018_00022_00015.png
#   inflating: gtsrb/train/18/00018_00022_00017.png
#   inflating: gtsrb/train/18/00018_00022_00018.png
#   inflating: gtsrb/train/18/00018_00022_00019.png
#   inflating: gtsrb/train/18/00018_00022_00020.png
#   inflating: gtsrb/train/18/00018_00022_00021.png
#   inflating: gtsrb/train/18/00018_00022_00022.png
#   inflating: gtsrb/train/18/00018_00022_00023.png
#   inflating: gtsrb/train/18/00018_00022_00024.png
#   inflating: gtsrb/train/18/00018_00022_00025.png
#   inflating: gtsrb/train/18/00018_00022_00026.png
#   inflating: gtsrb/train/18/00018_00022_00027.png
#   inflating: gtsrb/train/18/00018_00022_00028.png
#   inflating: gtsrb/train/18/00018_00022_00029.png
# ...
#   inflating: gtsrb/train/39/00039_00001_00003.png
#   inflating: gtsrb/train/39/00039_00001_00004.png
#   inflating: gtsrb/train/39/00039_00001_00005.png
#   inflating: gtsrb/train/39/00039_00001_00006.png
#   inflating: gtsrb/train/39/00039_00001_00007.png
#   inflating: gtsrb/train/39/00039_00001_00008.png
#   inflating: gtsrb/train/39/00039_00001_00009.png
#   inflating: gtsrb/train/39/00039_00001_00010.png
#   inflating: gtsrb/train/39/00039_00001_00011.png
#   inflating: gtsrb/train/39/00039_00001_00012.png
#   inflating: gtsrb/train/39/00039_00001_00013.png
#   inflating: gtsrb/train/39/00039_00001_00014.png
#   inflating: gtsrb/train/39/00039_00001_00015.png
#   inflating: gtsrb/train/39/00039_00001_00016.png
#   inflating: gtsrb/train/39/00039_00001_00017.png
#   inflating: gtsrb/train/39/00039_00001_00018.png
#   inflating: gtsrb/train/39/00039_00001_00019.png
#   inflating: gtsrb/train/39/00039_00001_00020.png
#   inflating: gtsrb/train/39/00039_00001_00021.png
#   inflating: gtsrb/train/39/00039_00001_00022.png
#   inflating: gtsrb/train/39/00039_00001_00023.png
#   inflating: gtsrb/train/39/00039_00001_00024.png
#   inflating: gtsrb/train/39/00039_00001_00025.png
#   inflating: gtsrb/train/39/00039_00001_00026.png
#   inflating: gtsrb/train/39/00039_00001_00027.png
#   inflating: gtsrb/train/39/00039_00001_00028.png
#   inflating: gtsrb/train/39/00039_00001_00029.png
#   inflating: gtsrb/train/39/00039_00002_00000.png
#   inflating: gtsrb/train/39/00039_00002_00001.png
#   inflating: gtsrb/train/39/00039_00002_00002.png
#   inflating: gtsrb/train/39/00039_00002_00003.png
#   inflating: gtsrb/train/39/00039_00002_00004.png
#   inflating: gtsrb/train/39/00039_00002_00005.png
#   inflating: gtsrb/train/39/00039_00002_00006.png
#   inflating: gtsrb/train/39/00039_00002_00007.png
#   inflating: gtsrb/train/39/00039_00002_00008.png
#   inflating: gtsrb/train/39/00039_00002_00009.png
#   inflating: gtsrb/train/39/00039_00002_00010.png
#   inflating: gtsrb/train/39/00039_00002_00011.png
#   inflating: gtsrb/train/39/00039_00002_00012.png
#   inflating: gtsrb/train/39/00039_00002_00013.png
#   inflating: gtsrb/train/39/00039_00002_00014.png
#   inflating: gtsrb/train/39/00039_00002_00015.png
#   inflating: gtsrb/train/39/00039_00002_00016.png
#   inflating: gtsrb/train/39/00039_00002_00017.png
#   inflating: gtsrb/train/39/00039_00002_00018.png
#   inflating: gtsrb/train/39/00039_00002_00019.png
#   inflating: gtsrb/train/39/00039_00002_00020.png
#   inflating: gtsrb/train/39/00039_00002_00021.png
#   inflating: gtsrb/train/39/00039_00002_00022.png
#   inflating: gtsrb/train/39/00039_00002_00023.png
#   inflating: gtsrb/train/39/00039_00002_00024.png
#   inflating: gtsrb/train/39/00039_00002_00025.png
#   inflating: gtsrb/train/39/00039_00002_00026.png
#   inflating: gtsrb/train/39/00039_00002_00027.png
#   inflating: gtsrb/train/39/00039_00002_00028.png
#   inflating: gtsrb/train/39/00039_00002_00029.png
#   inflating: gtsrb/train/39/00039_00003_00000.png
#   inflating: gtsrb/train/39/00039_00003_00001.png
#   inflating: gtsrb/train/39/00039_00003_00002.png
#   inflating: gtsrb/train/39/00039_00003_00003.png
#   inflating: gtsrb/train/39/00039_00003_00004.png
#   inflating: gtsrb/train/39/00039_00003_00005.png
#   inflating: gtsrb/train/39/00039_00003_00006.png
#   inflating: gtsrb/train/39/00039_00003_00007.png
#   inflating: gtsrb/train/39/00039_00003_00008.png
#   inflating: gtsrb/train/39/00039_00003_00009.png
#   inflating: gtsrb/train/39/00039_00003_00010.png
#   inflating: gtsrb/train/39/00039_00003_00011.png
#   inflating: gtsrb/train/39/00039_00003_00012.png
#   inflating: gtsrb/train/39/00039_00003_00013.png
#   inflating: gtsrb/train/39/00039_00003_00014.png
#   inflating: gtsrb/train/39/00039_00003_00015.png
#   inflating: gtsrb/train/39/00039_00003_00016.png
#   inflating: gtsrb/train/39/00039_00003_00017.png
#   inflating: gtsrb/train/39/00039_00003_00018.png
#   inflating: gtsrb/train/39/00039_00003_00019.png
#   inflating: gtsrb/train/39/00039_00003_00020.png
#   inflating: gtsrb/train/39/00039_00003_00021.png
#   inflating: gtsrb/train/39/00039_00003_00022.png
#   inflating: gtsrb/train/39/00039_00003_00023.png
#   inflating: gtsrb/train/39/00039_00003_00024.png
#   inflating: gtsrb/train/39/00039_00003_00025.png
#   inflating: gtsrb/train/39/00039_00003_00026.png
#   inflating: gtsrb/train/39/00039_00003_00027.png
#   inflating: gtsrb/train/39/00039_00003_00028.png
#   inflating: gtsrb/train/39/00039_00003_00029.png
#   inflating: gtsrb/train/39/00039_00004_00000.png
#   inflating: gtsrb/train/39/00039_00004_00001.png
#   inflating: gtsrb/train/39/00039_00004_00002.png
#   inflating: gtsrb/train/39/00039_00004_00003.png
#   inflating: gtsrb/train/39/00039_00004_00004.png
#   inflating: gtsrb/train/39/00039_00004_00005.png
#   inflating: gtsrb/train/39/00039_00004_00006.png
#   inflating: gtsrb/train/39/00039_00004_00007.png
#   inflating: gtsrb/train/39/00039_00004_00008.png
#   inflating: gtsrb/train/39/00039_00004_00009.png
#   inflating: gtsrb/train/39/00039_00004_00010.png
#   inflating: gtsrb/train/39/00039_00004_00011.png
#   inflating: gtsrb/train/39/00039_00004_00012.png
#   inflating: gtsrb/train/39/00039_00004_00013.png
#   inflating: gtsrb/train/39/00039_00004_00014.png
#   inflating: gtsrb/train/39/00039_00004_00015.png
#   inflating: gtsrb/train/39/00039_00004_00016.png
#   inflating: gtsrb/train/39/00039_00004_00017.png
#   inflating: gtsrb/train/39/00039_00004_00018.png
#   inflating: gtsrb/train/39/00039_00004_00019.png
#   inflating: gtsrb/train/39/00039_00004_00020.png
#   inflating: gtsrb/train/39/00039_00004_00021.png
#   inflating: gtsrb/train/39/00039_00004_00022.png
#   inflating: gtsrb/train/39/00039_00004_00023.png
#   inflating: gtsrb/train/39/00039_00004_00024.png
#   inflating: gtsrb/train/39/00039_00004_00025.png
#   inflating: gtsrb/train/39/00039_00004_00026.png
#   inflating: gtsrb/train/39/00039_00004_00027.png
#   inflating: gtsrb/train/39/00039_00004_00028.png
#   inflating: gtsrb/train/39/00039_00004_00029.png
#   inflating: gtsrb/train/39/00039_00005_00000.png
#   inflating: gtsrb/train/39/00039_00005_00001.png
#   inflating: gtsrb/train/39/00039_00005_00002.png
#   inflating: gtsrb/train/39/00039_00005_00003.png
#   inflating: gtsrb/train/39/00039_00005_00004.png
#   inflating: gtsrb/train/39/00039_00005_00005.png
#   inflating: gtsrb/train/39/00039_00005_00006.png
#   inflating: gtsrb/train/39/00039_00005_00007.png
#   inflating: gtsrb/train/39/00039_00005_00008.png
#   inflating: gtsrb/train/39/00039_00005_00009.png
#   inflating: gtsrb/train/39/00039_00005_00010.png
#   inflating: gtsrb/train/39/00039_00005_00011.png
#   inflating: gtsrb/train/39/00039_00005_00012.png
#   inflating: gtsrb/train/39/00039_00005_00013.png
#   inflating: gtsrb/train/39/00039_00005_00014.png
#   inflating: gtsrb/train/39/00039_00005_00015.png
#   inflating: gtsrb/train/39/00039_00005_00016.png
#   inflating: gtsrb/train/39/00039_00005_00017.png
#   inflating: gtsrb/train/39/00039_00005_00018.png
#   inflating: gtsrb/train/39/00039_00005_00019.png
#   inflating: gtsrb/train/39/00039_00005_00020.png
#   inflating: gtsrb/train/39/00039_00005_00021.png
#   inflating: gtsrb/train/39/00039_00005_00022.png
#   inflating: gtsrb/train/39/00039_00005_00023.png
#   inflating: gtsrb/train/39/00039_00005_00024.png
#   inflating: gtsrb/train/39/00039_00005_00025.png
#   inflating: gtsrb/train/39/00039_00005_00026.png
#   inflating: gtsrb/train/39/00039_00005_00027.png
#   inflating: gtsrb/train/39/00039_00005_00028.png
#   inflating: gtsrb/train/39/00039_00005_00029.png
#   inflating: gtsrb/train/39/00039_00006_00000.png
#   inflating: gtsrb/train/39/00039_00006_00001.png
#   inflating: gtsrb/train/39/00039_00006_00002.png
#   inflating: gtsrb/train/39/00039_00006_00003.png
#   inflating: gtsrb/train/39/00039_00006_00004.png
#   inflating: gtsrb/train/39/00039_00006_00005.png
#   inflating: gtsrb/train/39/00039_00006_00006.png
#   inflating: gtsrb/train/39/00039_00006_00007.png
#   inflating: gtsrb/train/39/00039_00006_00008.png
#   inflating: gtsrb/train/39/00039_00006_00009.png
#   inflating: gtsrb/train/39/00039_00006_00010.png
#   inflating: gtsrb/train/39/00039_00006_00011.png
#   inflating: gtsrb/train/39/00039_00006_00012.png
#   inflating: gtsrb/train/39/00039_00006_00013.png
#   inflating: gtsrb/train/39/00039_00006_00014.png
#   inflating: gtsrb/train/39/00039_00006_00015.png
#   inflating: gtsrb/train/39/00039_00006_00016.png
#   inflating: gtsrb/train/39/00039_00006_00017.png
#   inflating: gtsrb/train/39/00039_00006_00018.png
#   inflating: gtsrb/train/39/00039_00006_00019.png
#   inflating: gtsrb/train/39/00039_00006_00020.png
#   inflating: gtsrb/train/39/00039_00006_00021.png
#   inflating: gtsrb/train/39/00039_00006_00022.png
#   inflating: gtsrb/train/39/00039_00006_00023.png
#   inflating: gtsrb/train/39/00039_00006_00024.png
#   inflating: gtsrb/train/39/00039_00006_00025.png
#   inflating: gtsrb/train/39/00039_00006_00026.png
#   inflating: gtsrb/train/39/00039_00006_00027.png
#   inflating: gtsrb/train/39/00039_00006_00028.png
#   inflating: gtsrb/train/39/00039_00006_00029.png
#   inflating: gtsrb/train/39/00039_00007_00000.png
#   inflating: gtsrb/train/39/00039_00007_00001.png
#   inflating: gtsrb/train/39/00039_00007_00002.png
#   inflating: gtsrb/train/39/00039_00007_00003.png
#   inflating: gtsrb/train/39/00039_00007_00004.png
#   inflating: gtsrb/train/39/00039_00007_00005.png
#   inflating: gtsrb/train/39/00039_00007_00006.png
#   inflating: gtsrb/train/39/00039_00007_00007.png
#   inflating: gtsrb/train/39/00039_00007_00008.png
#   inflating: gtsrb/train/39/00039_00007_00009.png
#   inflating: gtsrb/train/39/00039_00007_00010.png
#   inflating: gtsrb/train/39/00039_00007_00011.png
#   inflating: gtsrb/train/39/00039_00007_00012.png
#   inflating: gtsrb/train/39/00039_00007_00013.png
#   inflating: gtsrb/train/39/00039_00007_00014.png
#   inflating: gtsrb/train/39/00039_00007_00015.png
#   inflating: gtsrb/train/39/00039_00007_00016.png
#   inflating: gtsrb/train/39/00039_00007_00017.png
#   inflating: gtsrb/train/39/00039_00007_00018.png
#   inflating: gtsrb/train/39/00039_00007_00019.png
#   inflating: gtsrb/train/39/00039_00007_00020.png
#   inflating: gtsrb/train/39/00039_00007_00021.png
#   inflating: gtsrb/train/39/00039_00007_00022.png
#   inflating: gtsrb/train/39/00039_00007_00023.png
#   inflating: gtsrb/train/39/00039_00007_00024.png
#   inflating: gtsrb/train/39/00039_00007_00025.png
#   inflating: gtsrb/train/39/00039_00007_00026.png
#   inflating: gtsrb/train/39/00039_00007_00027.png
#   inflating: gtsrb/train/39/00039_00007_00028.png
#   inflating: gtsrb/train/39/00039_00007_00029.png
#   inflating: gtsrb/train/39/00039_00008_00000.png
#   inflating: gtsrb/train/39/00039_00008_00001.png
#   inflating: gtsrb/train/39/00039_00008_00002.png
#   inflating: gtsrb/train/39/00039_00008_00003.png
#   inflating: gtsrb/train/39/00039_00008_00004.png
#   inflating: gtsrb/train/39/00039_00008_00005.png
#   inflating: gtsrb/train/39/00039_00008_00006.png
#   inflating: gtsrb/train/39/00039_00008_00007.png
#   inflating: gtsrb/train/39/00039_00008_00008.png
#   inflating: gtsrb/train/39/00039_00008_00009.png
#   inflating: gtsrb/train/39/00039_00008_00010.png
#   inflating: gtsrb/train/39/00039_00008_00011.png
#   inflating: gtsrb/train/39/00039_00008_00012.png
#   inflating: gtsrb/train/39/00039_00008_00013.png
#   inflating: gtsrb/train/39/00039_00008_00014.png
#   inflating: gtsrb/train/39/00039_00008_00015.png
#   inflating: gtsrb/train/39/00039_00008_00016.png
#   inflating: gtsrb/train/39/00039_00008_00017.png
#   inflating: gtsrb/train/39/00039_00008_00018.png
#   inflating: gtsrb/train/39/00039_00008_00019.png
#   inflating: gtsrb/train/39/00039_00008_00020.png
#   inflating: gtsrb/train/39/00039_00008_00021.png
#   inflating: gtsrb/train/39/00039_00008_00022.png
#   inflating: gtsrb/train/39/00039_00008_00023.png
#   inflating: gtsrb/train/39/00039_00008_00024.png
#   inflating: gtsrb/train/39/00039_00008_00025.png
#   inflating: gtsrb/train/39/00039_00008_00026.png
#   inflating: gtsrb/train/39/00039_00008_00027.png
#   inflating: gtsrb/train/39/00039_00008_00028.png
#   inflating: gtsrb/train/39/00039_00008_00029.png
#   inflating: gtsrb/train/39/00039_00009_00000.png
#   inflating: gtsrb/train/39/00039_00009_00001.png
#   inflating: gtsrb/train/39/00039_00009_00002.png
#   inflating: gtsrb/train/39/00039_00009_00003.png
#   inflating: gtsrb/train/39/00039_00009_00004.png
#   inflating: gtsrb/train/39/00039_00009_00005.png
#   inflating: gtsrb/train/39/00039_00009_00006.png
#   inflating: gtsrb/train/39/00039_00009_00007.png
#   inflating: gtsrb/train/39/00039_00009_00008.png
#   inflating: gtsrb/train/39/00039_00009_00009.png
#   inflating: gtsrb/train/39/00039_00009_00010.png
#   inflating: gtsrb/train/39/00039_00009_00011.png
#   inflating: gtsrb/train/39/00039_00009_00012.png
#   inflating: gtsrb/train/39/00039_00009_00013.png
#   inflating: gtsrb/train/39/00039_00009_00014.png
#   inflating: gtsrb/train/39/00039_00009_00015.png
#   inflating: gtsrb/train/39/00039_00009_00016.png
#   inflating: gtsrb/train/39/00039_00009_00017.png
#   inflating: gtsrb/train/39/00039_00009_00018.png
#   inflating: gtsrb/train/39/00039_00009_00019.png
#   inflating: gtsrb/train/39/00039_00009_00020.png
#   inflating: gtsrb/train/39/00039_00009_00021.png
#   inflating: gtsrb/train/39/00039_00009_00022.png
#   inflating: gtsrb/train/39/00039_00009_00023.png
#   inflating: gtsrb/train/39/00039_00009_00024.png
#   inflating: gtsrb/train/39/00039_00009_00025.png
#   inflating: gtsrb/train/39/00039_00009_00026.png
#   inflating: gtsrb/train/39/00039_00009_00027.png
#   inflating: gtsrb/train/39/00039_00009_00028.png
#   inflating: gtsrb/train/39/00039_00009_00029.png
#   inflating: gtsrb/Meta.csv
#   inflating: gtsrb/Test.csv
#   inflating: gtsrb/Train.csv
# [INFO] loading training and testing data...
# [INFO] processed 1000 total images.
# [INFO] processed 2000 total images.
# [INFO] processed 3000 total images.
# [INFO] processed 4000 total images.
# [INFO] processed 5000 total images.
# [INFO] processed 6000 total images.
# [INFO] processed 7000 total images.
# [INFO] processed 8000 total images.
# [INFO] processed 9000 total images.
# [INFO] processed 10000 total images.
# [INFO] processed 11000 total images.
# [INFO] processed 12000 total images.
# [INFO] processed 13000 total images.
# [INFO] processed 14000 total images.
# [INFO] processed 15000 total images.
# [INFO] processed 16000 total images.
# [INFO] processed 17000 total images.
# [INFO] processed 18000 total images.
# [INFO] processed 19000 total images.
# [INFO] processed 20000 total images.
# [INFO] processed 21000 total images.
# [INFO] processed 22000 total images.
# [INFO] processed 23000 total images.
# [INFO] processed 24000 total images.
# [INFO] processed 25000 total images.
# [INFO] processed 26000 total images.
# [INFO] processed 27000 total images.
# [INFO] processed 28000 total images.
# [INFO] processed 29000 total images.
# [INFO] processed 30000 total images.
# [INFO] processed 31000 total images.
# [INFO] processed 32000 total images.
# [INFO] processed 33000 total images.
# [INFO] processed 34000 total images.
# [INFO] processed 35000 total images.
# [INFO] processed 36000 total images.
# [INFO] processed 37000 total images.
# [INFO] processed 38000 total images.
# [INFO] processed 39000 total images.
# [INFO] processed 1000 total images.
# [INFO] processed 2000 total images.
# [INFO] processed 3000 total images.
# [INFO] processed 4000 total images.
# [INFO] processed 5000 total images.
# [INFO] processed 6000 total images.
# [INFO] processed 7000 total images.
# [INFO] processed 8000 total images.
# [INFO] processed 9000 total images.
# [INFO] processed 10000 total images.
# [INFO] processed 11000 total images.
# [INFO] processed 12000 total images.
# [INFO] saving training and testing data...

# %%
# przygotowanie do uczenia modelu
# liczba etykiet
numLabels = trainY.shape[1]

# liczba epok (iteracji algorytmu uczenia)
NUM_EPOCHS = 15

# współczynnik uczenia
INIT_LR = 1e-3

# rozmiar "wsadu" do batch normalization (https://en.wikipedia.org/wiki/Batch_normalization)
BS = 64

# wczytanie zbioru uczącego i testowego
with open('train_test.pickle', 'rb') as f:
    trainX, trainY, testX, testY = pickle.load(f)

# Stworzenie obiektu do augmentacji danych
# Co to jest augmentacja? Ogólnie jest to "sztuczne" zwiększenie liczebności zbioru uczącego.
# Jak można się domyślać po nazwach argumentów, tu obejmuje takie operacje jak: obrót, skalowanie, przesunięcie czy zniekształcenie.

aug = ImageDataGenerator(
		rotation_range=10,
		zoom_range=0.15,
		width_shift_range=0.1,
		height_shift_range=0.1,
		shear_range=0.15,
		horizontal_flip=False,
		vertical_flip=False,
		fill_mode="nearest"
)

# Inicjalizacja optymalizatora oraz kompilacja modułu
# Parametr LR (Learning Rate) mówi o tym, jak bardzo sieć się uczy (jak bardzo możemy zmienić parametry w danym kroku).
# Proszę zwrócić uwagę, że ustawia się również jego zanikanie (decay).
# Upraszczając (znowu): w poszukiwaniu optimum lokalnego w przestrzeni rozwiązań (bo do tego ostatecznie sprowadza się problem uczenia),
# na początku dopuszczamy duże przesunięcia, a z czasem coraz mniejsze.

print("[INFO] compiling model...")

opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / (NUM_EPOCHS * 0.5))
model = TrafficSignNet.build(width=32, height=32, depth=3, classes=numLabels)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])

# wyliczanie wag dla klas - wskazanie dla modułu, że występuje problem z różną liczebnością zbioru uczącego
classTotals = trainY.sum(axis=0)
classWeight = classTotals.max() / classTotals
classWeightD = { x: classWeight[x] for x in range(0, classWeight.shape[0]) }

print("[INFO] model ready to learn!")
# Out:
# [INFO] compiling model...
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [INFO] model ready to learn!

# %%
# Uczenie modelu
# To może chwilę trwać - ograniczyliśmy liczbę epok (iteracji procesu) do 15.
# Ogólnie jest to etap, który dobrze można akcelerować na GPU, przy czym lokalna konfiguracja TensorFlow/Keras do współpracy z GPU nie jest prosta
# (i na pewno trwa znacznie dłużej niż to uczenie).
# W kolejnych epokach wyświetlają się wskaźniki:
# - accuracy - dokładność na zbiorze uczącym (powinna rosnąć)
# - loss - funkcja błędu dla zbioru uczącego (powinna maleć)
# - val_accuracy - dokładność dla zbioru walidacyjnego (powinna rosnąć)
# - val_loss - funkcja błędu na zbiorze walidacyjnym (powinna maleć)

# Zbiory uczące i testowe są rozłączne, aby móc zaobserwować zjawisko "przeuczenia" modelu (ang. overfitting).
# Najkrócej ujmując, jest to analogia nauki "na pamięć". Model dobrze nauczy się danych uczących, ale gorzej będzie sobie radził na innych.

print("[INFO] training network...")
H = model.fit(
		aug.flow(trainX, trainY, batch_size=BS),
		validation_data=(testX, testY),
		steps_per_epoch=trainX.shape[0] // BS,
		epochs=NUM_EPOCHS,
		class_weight=classWeightD,
		verbose=1
)

# zapis sieci na dysk - coby nie trzeba było drugi raz uczyć
print("[INFO] serializing network to 'trafficsignnet.keras'...")
model.save("trafficsignnet.keras")
print("[INFO] training network done.")
# Out:
# [INFO] training network...
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/15
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 54s 59ms/step - accuracy: 0.0726 - loss: 9.6484 - val_accuracy: 0.0434 - val_loss: 3.9060
# Epoch 2/15
#   1/612 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.2031 - loss: 5.7604
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2031 - loss: 5.7604 - val_accuracy: 0.0481 - val_loss: 3.8610
# Epoch 3/15
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 64s 41ms/step - accuracy: 0.3283 - loss: 5.1082 - val_accuracy: 0.5107 - val_loss: 1.4072
# Epoch 4/15
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5000 - loss: 4.8793 - val_accuracy: 0.5255 - val_loss: 1.3705
# Epoch 5/15
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.5120 - loss: 3.4229 - val_accuracy: 0.5959 - val_loss: 1.1850
# Epoch 6/15
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5469 - loss: 2.5659 - val_accuracy: 0.5880 - val_loss: 1.2254
# Epoch 7/15
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 40s 41ms/step - accuracy: 0.6350 - loss: 2.4526 - val_accuracy: 0.6190 - val_loss: 1.1924
# Epoch 8/15
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6562 - loss: 1.5788 - val_accuracy: 0.6165 - val_loss: 1.2057
# Epoch 9/15
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 39s 41ms/step - accuracy: 0.7049 - loss: 1.9176 - val_accuracy: 0.7325 - val_loss: 0.7916
# Epoch 10/15
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7344 - loss: 2.4580 - val_accuracy: 0.7386 - val_loss: 0.7708
# Epoch 11/15
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 40s 40ms/step - accuracy: 0.7600 - loss: 1.5551 - val_accuracy: 0.5408 - val_loss: 1.7857
# Epoch 12/15
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6719 - loss: 2.1245 - val_accuracy: 0.5502 - val_loss: 1.7306
# Epoch 13/15
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 40s 39ms/step - accuracy: 0.7874 - loss: 1.3566 - val_accuracy: 0.8070 - val_loss: 0.6099
# Epoch 14/15
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8281 - loss: 1.1340 - val_accuracy: 0.8121 - val_loss: 0.5941
# Epoch 15/15
# 612/612 ━━━━━━━━━━━━━━━━━━━━ 40s 40ms/step - accuracy: 0.8248 - loss: 1.0995 - val_accuracy: 0.7677 - val_loss: 0.7257
# [INFO] serializing network to 'trafficsignnet.keras'...
# [INFO] training network done.

# %% [markdown]
# ## Ewaluacja
#
# Mając dany znak i wynik klasyfikacji, mamy 4 możliwości:
# - TP (_True Positive_) - wynik klasyfikacji i stan faktyczny są pozytywne,
# - FP (_False Positive_) - klasyfikacja wskazuje na znak X, ale stan faktyczny to nie X,
# - FN (_False Negative_) - klasyfikacja wskazuje, że to nie znak X, natomiast stan faktyczny to X,
# - TN (_True Negative_) - klasyfikacja wskazuje, że to nie znak X i to istotnie nie jest znak X.
#
# Na tej podstawie można konstruować wskaźniki:
# - **precision** = TP / (TP + FP)
# - **recall** = TP / (TP + FN)
# - **f1-score** = 2 * precision * recall / (precision + recall)
#
# Szerszy ich opis można znaleźć na [Wikipedii](https://en.wikipedia.org/wiki/Sensitivity_and_specificity).
#
# Parametr *support* oznacza liczbę próbek.
#
# Warto na chwilę się zastanowić nad tym, co oznaczają te wskaźniki.
# Precyzja (precision) będzie tym większa, im mniej będzie FP, czyli sytuacji, że znak różny od X będzie uznany za X (należący do ewaluowanej klasy).
# Natomiast czułość (recall) będzie tym większa, im mniej będzie FN, czyli sytuacji, że znak X (należący do rozpatrywanej klasy) nie będzie uznany za X.
#
# Należy zwrócić uwagę, że:
# - w idealnym przypadku (brak błędów) oba powinny mieć wartość 1,
# - są poniekąd przeciwstawne - wszystko zależy od tego, czy nasz klasyfikator jest mniej, czy bardziej restrykcyjny,
# - f1-score, jako średnia harmoniczna, łączy oba wskaźniki.
#
#
# Proszę jeszcze zwrócić uwagę na rysunek `train.png` - wyświetlić i zastanowić się, co oznacza.

# %%
# ewaluacja modelu (sprawdzenie, jak się nauczył)
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=BS)
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=labelNames))

# wykres funkcji kosztu i dokładności
N = np.arange(0, NUM_EPOCHS)
plt.style.use("ggplot")
plt.figure()

plt.plot(N, H.history["loss"], label="train_loss")
plt.plot(N, H.history["val_loss"], label="val_loss")
plt.plot(N, H.history["accuracy"], label="train_acc")
plt.plot(N, H.history["val_accuracy"], label="val_acc")

plt.title("Training Loss and Accuracy on Dataset")
plt.xlabel("Epoch no")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.savefig("train.png")
# Out:
# [INFO] evaluating network...
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
#                                precision    recall  f1-score   support
#
#          Speed limit (20km/h)       0.96      0.37      0.53        60
#          Speed limit (30km/h)       0.98      0.64      0.77       720
#          Speed limit (50km/h)       0.99      0.40      0.57       750
#          Speed limit (60km/h)       0.97      0.66      0.78       450
#          Speed limit (70km/h)       0.73      0.83      0.78       660
#          Speed limit (80km/h)       0.37      0.29      0.33       630
#   End of speed limit (80km/h)       0.99      0.63      0.77       150
#         Speed limit (100km/h)       0.37      0.81      0.51       450
#         Speed limit (120km/h)       0.51      0.91      0.65       450
#                    No passing       0.99      0.69      0.81       480
#  No passing veh over 3.5 tons       0.89      0.90      0.89       660
#  Right-of-way at intersection       0.99      0.49      0.66       420
#                 Priority road       1.00      0.96      0.98       690
#                         Yield       1.00      0.98      0.99       720
#                          Stop       1.00      0.96      0.98       270
#                   No vehicles       0.66      0.99      0.79       210
#     Veh > 3.5 tons prohibited       0.72      0.99      0.83       150
#                      No entry       0.97      0.99      0.98       360
#               General caution       0.96      0.64      0.77       390
#          Dangerous curve left       1.00      0.47      0.64        60
#         Dangerous curve right       0.39      0.92      0.55        90
#                  Double curve       0.97      0.40      0.57        90
#                    Bumpy road       0.80      0.85      0.83       120
#                 Slippery road       0.69      0.12      0.20       150
#     Road narrows on the right       0.94      0.81      0.87        90
#                     Road work       0.90      0.95      0.93       480
#               Traffic signals       0.57      0.88      0.69       180
#                   Pedestrians       0.82      0.83      0.83        60
#             Children crossing       0.88      0.81      0.84       150
#             Bicycles crossing       0.90      0.59      0.71        90
#            Beware of ice/snow       0.24      0.83      0.37       150
#         Wild animals crossing       0.84      0.90      0.87       270
#    End speed + passing limits       0.97      1.00      0.98        60
#              Turn right ahead       0.99      0.98      0.98       210
#               Turn left ahead       0.47      1.00      0.64       120
#                    Ahead only       0.99      0.67      0.80       390
#          Go straight or right       0.98      0.84      0.91       120
#           Go straight or left       0.77      1.00      0.87        60
#                    Keep right       0.95      0.99      0.97       690
#                     Keep left       1.00      0.84      0.92        90
#          Roundabout mandatory       0.65      0.67      0.66        90
#             End of no passing       0.93      0.72      0.81        60
# End no passing veh > 3.5 tons       0.60      0.97      0.74        90
#
#                      accuracy                           0.77     12630
#                     macro avg       0.82      0.77      0.76     12630
#                  weighted avg       0.84      0.77      0.77     12630

# %% [markdown]
# ## Wnioskowanie
#
# Kiedy już mamy nauczony model, to możemy go użyć do wnioskowania (ang. inference).
# Wtedy na wejście podajemy zdjęcie znaku, a na wyjściu uzyskujemy informację, co to za znak.
#
# Uwaga: proszę utworzyć folder `examples`.
#
# Na samym końcu patrzymy, co nam wyszło.
# Z uwagi na ograniczoną liczbę iteracji - "szału nie ma", ale i tak znaki o lepszej jakości powinny być rozpoznane poprawnie.

# %%
# wczytujemy model
print("[INFO] loading model...")
model = load_model("trafficsignnet.keras")

# wczytujemy nazwy klas (ponownie)
labelNames = open("signnames.csv").read().strip().split("\n")[1:]
labelNames = [l.split(",")[0] for l in labelNames]

# wczytujemy obrazy, mieszamy je i wybieramy podzbiór
print("[INFO] predicting...")
imagePaths = list(paths.list_images(f"{dataset}/Test"))
random.shuffle(imagePaths)
imagePaths = imagePaths[:25]

# pętla po obrazach
for (i, imagePath) in enumerate(imagePaths):
		# wczytujemy obraz, skalujemy i wyrównujemy histogram - dokładnie tak, jak wcześniej
		image = io.imread(imagePath)
		image = transform.resize(image, (32, 32))
		image = exposure.equalize_adapthist(image, clip_limit=0.1)

		# skalujemy do wartości [0; 1]
		image = image.astype("float32") / 255.0
		image = np.expand_dims(image, axis=0)

		# przeprowadzamy wnioskowanie
		preds = model.predict(image)

		# wybieramy najbardziej prawdopodobną odpowiedź
		j = preds.argmax(axis=1)[0]
		label = labelNames[j]

		# wizualizacja i zapis do pliku
		image = cv2.imread(imagePath)
		image = imutils.resize(image, width=128)
		cv2.putText(image, label, (5, 15), cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 0, 255), 2)
		p = os.path.sep.join(["examples", "{}.png".format(i)])
		cv2.imwrite(p, image)

print("[INFO] done.")
# Out:
# [INFO] loading model...
# [INFO] predicting...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# [INFO] done.
